# %% [markdown]
# 1. Read in all of the predicted (major topic) congress speech data (from multiple files. keep just party, cong_number, text, date, topic)
# 2. Keep only rows where party == democrat or republican
# 3. Partition the data by major topic.
# 4. Chunk into 2.5k character length rows
# 5. Tokenize:
# 	a. Remove Roberts Rules tokens
# 	b. Keep only tokens in the news data
# 	c. Only tokens that appear in 10 documents or more
# 6. Within each topic, predict party. Use Elastic Net.
# 7. This will give you 21 models --- one for each topic
# 8. Output classification success of each.
# 9. Output top 20 Republican and Democrat words for each model.

# %%
import pandas as pd
import numpy as np
import time
from sklearn.externals import joblib

# %%
import nltk
from nltk import word_tokenize          
from nltk.stem.porter import PorterStemmer
import re
import string

stemmer = PorterStemmer()
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

#def tokenize(text):
#    tokens = nltk.word_tokenize(text)
#    stems = stem_tokens(tokens, stemmer)
#    return stems

def tokenize(text):
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    return stems

# %matplotlib inline
import matplotlib.pyplot as plt
from pandas_confusion import ConfusionMatrix
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import svm
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.cross_validation import train_test_split

with open('../roberts_rules/all_text.txt', 'rt') as f:
    text = f.read()
text = text.decode('ascii', 'ignore')
text = re.sub(r'\d+', '', text)

vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3)) 
vect.fit([text])
roberts_rules = set(vect.get_feature_names())

def most_informative_feature_for_class(vectorizer, classifier, classlabel, n=10):
    labelid = list(classifier.classes_).index(classlabel)
    feature_names = vectorizer.get_feature_names()
    topn = sorted(zip(classifier.coef_[labelid], feature_names))[-n:]

    for coef, feat in topn:
        print classlabel, feat, coef

def most_informative_feature_for_class_svm(vectorizer, classifier,  n=10):
    labelid = 3 # this is the coef we're interested in. 
    feature_names = vectorizer.get_feature_names()
    svm_coef = classifier.coef_.toarray() 
    topn = sorted(zip(svm_coef[labelid], feature_names))[-n:]

    for coef, feat in topn:
        print feat, coef

def print_top10(vectorizer, clf, class_labels):
    """Prints features with the highest coefficient values, per class"""
    feature_names = vectorizer.get_feature_names()
    for i, class_label in enumerate(class_labels):
        top10 = np.argsort(clf.coef_[i])[-10:]
        print("%s: %s" % (class_label,
              " | ".join(feature_names[j] for j in top10)))

def get_top_features(vectorizer, clf, class_labels, n=20):
    """Prints features with the highest coefficient values, per class"""
    feature_names = vectorizer.get_feature_names()
    top_features = {}
    for i, class_label in enumerate(class_labels):
        topN = np.argsort(clf.coef_[i])[-n:]
        top_features[class_label] = [feature_names[j] for j in topN][::-1]
    return top_features

def show_most_informative_features(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print "\t%.4f\t%-20s\t\t%.4f\t%-20s" % (coef_1, fn_1, coef_2, fn_2)

# %% [markdown]
# ## Read Predicted Congress dataset

# %%
adf = None
for nth in range(107, 113):
    print nth
    df = pd.read_csv('../data/congress_%d_predict_major_label.csv' % nth) #, nrows=10)
    if adf is None:
        adf = df
    else:
        adf = pd.concat([adf, df])
adf
# Out:
# 107
# 108
# 109
# 110
# 111
# 112
#              date                                               text  party  \
# 0      2002-03-19  mr speaker yield minut gentleman virginia mr m...    100
# 1      2002-11-19  mr speaker would like submit appropri congress...    100
# 2      2002-06-06  mr speaker yesterday flight lo angel delay dep...    100
# 3      2002-03-06  mr speaker earlier today unabl cast vote two r...    100
# 4      2002-04-16  mr speaker thank gentleman yield time mr speak...    100
# 5      2002-10-01  mr speaker yield minut gentlewoman new york ms...    100
# 6      2001-10-16  mr speaker friday octob unavoid miss two roll ...    100
# 7      2002-05-09  mr chairman although disappoint rule bodi rise...    100
# 8      2002-10-01  mr speaker yield minut gentlewoman texa ms edd...    100
# 9      2002-10-01  mr speaker yield minut gentleman new jersey mr...    100
# 10     2002-06-17  madam speaker rise today strong support puuhon...    100
# 11     2002-10-01  mr speaker yield minut gentleman california mr...    100
# 12     2002-06-21             mr speaker demand gentleman word taken    100
# 13     2002-10-01  mr speaker yield minut gentleman wisconsin mr ...    100
# 14     2001-01-31  mr speaker earlier today unavoid absent three ...    100
# 15     2002-10-01  mr speaker ask unanim consent extend debat tim...    100
# 16     2002-10-07  mr speaker rise today join pay tribut great am...    100
# 17     2002-03-19  mr speaker yield time may consum mr speaker ri...    100
# 18     2002-10-01  mr speaker patsi move gentleman north carolina...    100
# 19     2002-07-23  mr speaker yesterday morn unavoid detain unabl...    100
# 20     2001-06-14  mr speaker yesterday june unavoid absent unabl...    100
# 21     2002-04-18  mr speaker nativ american sacr land attack nev...    100
# 22     2001-11-28  mr chairman good friend gentleman new york mr ...    100
# 23     2002-10-01  mr speaker yield minut gentlewoman california ...    100
# 24     2001-09-21  mr speaker yield time may consum gentleman mis...    100
# 25     2002-10-01  mr speaker yield minut gentleman new york mr g...    100
# 26     2002-10-01  mr speaker yield minut gentlewoman district co...    100
# 27     2001-02-07  mr speaker want particularli thank chairman to...    100
# 28     2002-10-01  mr speaker yield time may consum gentleman cal...    100
# 29     2002-03-19                  mr speaker yield back balanc time    100
# ...           ...                                                ...    ...
# 74618  2011-07-14  mr chairman yield time may consum nation unemp...    200
# 74619  2011-10-05  mr speaker yesterday opportun meet hilltop res...    200
# 74620  2011-07-14                         yield gentleman new jersey    200
# 74621  2011-12-14  mr speaker rise today support hr iran threat r...    200
# 74622  2011-07-18  thank colleagu arizona learn word eloqu word q...    200
# 74623  2011-05-03  mr chair good peopl indiana want job know know...    200
# 74624  2011-07-30  madam speaker need cut spend need control spen...    200
# 74625  2011-07-19  need plan presid need certainti restor market ...    200
# 74626  2011-06-14  mr chairman move strike last word act chair ge...    200
# 74627  2012-05-31  mr speaker rise today talk import work broadca...    200
# 74628  2011-07-18  thank gentleman arizona observ know presid sai...    200
# 74629  2011-06-14  madam chair amend desk act chair clerk report ...    200
# 74630  2011-04-14  mr chairman good peopl indiana want job know c...    200
# 74631  2012-02-02  mr speaker rise today support hr baselin refor...    200
# 74632  2012-03-06  madam speaker rise today ve never prouder call...    200
# 74633  2012-03-07  mr speaker rise today ve never prouder call so...    200
# 74634  2011-01-24  mr speaker rise today honor privat first class...    200
# 74635  2012-05-16  want thank friend tom ellsworth wife elsi trav...    200
# 74636  2011-07-14            amend desk act chair clerk design amend    200
# 74637  2011-04-14  madam chair much discuss today share sacrific ...    200
# 74638  2011-07-14  yield back balanc time act chair question amen...    200
# 74639  2011-07-14                            yield gentleman indiana    200
# 74640  2011-06-14                       yield honor colleagu georgia    200
# 74641  2011-06-14  madam chair amend quit simpl amend would simpl...    200
# 74642  2011-05-25  rise support rule hr us marin understand impor...    200
# 74643  2011-10-26  mr speaker rise along congressman mike penc ho...    200
# 74644  2011-07-19  madam speaker record last night speak cut cap ...    200
# 74645  2011-05-24  mr chairman former us marin understand import ...    200
# 74646  2011-07-18  thank colleagu arizona said coupl thing would ...    200
# 74647  2011-11-02  thank gentleman minnesota leadership certainli...    200
#
#        topic  cong_number
# 0         20          107
# 1         21          107
# 2          1          107
# 3          3          107
# 4         20          107
# 5         15          107
# 6          7          107
# 7         16          107
# 8         19          107
# 9         20          107
# 10        21          107
# 11         5          107
# 12         3          107
# 13         7          107
# 14         1          107
# 15        16          107
# 16         2          107
# 17        16          107
# 18        21          107
# 19         3          107
# 20         3          107
# 21        21          107
# 22        10          107
# 23         3          107
# 24         3          107
# 25         3          107
# 26        20          107
# 27        20          107
# 28         3          107
# 29         3          107
# ...      ...          ...
# 74618      8          112
# 74619      3          112
# 74620     10          112
# 74621     16          112
# 74622      1          112
# 74623      1          112
# 74624      3          112
# 74625      7          112
# 74626      3          112
# 74627     21          112
# 74628     21          112
# 74629     21          112
# 74630      5          112
# 74631      1          112
# 74632     16          112
# 74633     16          112
# 74634     16          112
# 74635      3          112
# 74636     21          112
# 74637      1          112
# 74638     21          112
# 74639      3          112
# 74640      3          112
# 74641      1          112
# 74642     16          112
# 74643     13          112
# 74644      3          112
# 74645     16          112
# 74646      3          112
# 74647      3          112
#
# [592270 rows x 5 columns]

# %%
df = df[df.party.isin([100, 200])]

# %% [markdown]
# ## Split long bill to smaller chunk (2500 chars)

# %%
import re
import textwrap

def insert_chars_split_marker(text, cc=2500):
    # FIXME: text still has number
    text = re.sub('\d+', '', text)
    out = '|'.join(textwrap.wrap(text, cc))
    return out

def insert_words_split_marker(text, wc=500):
    text = re.sub('\d+', '', text)
    words = text.split()
    out = ''
    for i, w in enumerate(words):
        if i != 0 and i % wc == 0:
            out += '|' + w
        else:
            out += ' ' + w
    return out

# %%
def remove_roberts_rules(all_vocab):
    vocab = []
    i = 0
    for a in all_vocab:
        if a not in roberts_rules:
            vocab.append(a)
        else:
            #print a
            i += 1
    print("Removed {0:d}".format(i))
    print("Total {0:d}".format(len(vocab)))
    return vocab

# %%
def get_most_informative_features(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top_a = coefs_with_fns[:n]
    top_b = coefs_with_fns[:-(n + 1):-1]
    return top_a, top_b

# %%
for t in df.topic.unique():
    # FIXME: skip topic == 12
    if t == 12:
        continue

    sdf = df[df.topic == t]
    print t, len(sdf)
    
    if True:
        # split long text to multiple rows
        sdf.loc[:, 'text'] = sdf.text.astype(str).apply(lambda c: insert_chars_split_marker(c, 2500))
        s = sdf['text'].str.split('|', expand=True).stack()
        i = s.index.get_level_values(0)
        new_df = sdf.loc[i].copy()
        new_df['chunk'] = s.index.get_level_values(1)
        new_df['text'] = s.values
        sdf = new_df.reset_index(drop=True)
    
    print t, len(sdf)
    vect = CountVectorizer(ngram_range=(2, 3), min_df=10) 
    vect.fit(sdf.text)
    print len(vect.get_feature_names())
    
    vocab = remove_roberts_rules(vect.vocabulary_)
    print len(vocab)
    
    # take out vocab doesn't in news dataset
    ng_df = pd.DataFrame(vocab)
    ng_df.columns = ['ngram']
    ng_df['found'] = False
    
    for ndf in pd.read_csv('../data/major_%s_news_predict.csv' % t, iterator=True, chunksize=5000, usecols=['text']):
        text = ndf.text.str.cat(sep=' ')
        all_ng = ng_df[~ng_df.found].ngram
        print len(text), len(all_ng)
        for i, ng in enumerate(all_ng):
            if ng in text:
                ng_df.loc[ng_df.ngram == ng, 'found'] = True
                #print i, ng #, sum(ndf.text.str.contains(ng))
                #print i,
            #break
        #print
        #break
    vocab = ng_df[ng_df.found].ngram.tolist()
    ng_df[ng_df.found].to_csv('../data/major_%d_congress_23gram.csv' % t, index=False)

    X = sdf.text
    y = sdf.party

    X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

    vect = CountVectorizer(ngram_range=(2, 3), min_df=10, vocabulary=vocab)

    X_train = vect.transform(X_train)
    transformer = TfidfTransformer()
    X_train = transformer.fit_transform(X_train)

    X_test = vect.transform(X_test)
    transformer = TfidfTransformer()
    X_test = transformer.fit_transform(X_test)

    from sklearn.linear_model import SGDClassifier

    elastic_clf = SGDClassifier(loss='log', alpha=.00002, n_iter=200, penalty="elasticnet")
    t0 = time.time()
    elastic_clf.fit(X_train, y_train)
    t1 = time.time()
    prediction_elastic = elastic_clf.predict(X_test)
    t2 = time.time()
    time_elastic_train = t1-t0
    time_elastic_predict = t2-t1

    print("Results for Elastic Net")
    print("Training time: %fs; Prediction time: %fs" % (time_elastic_train, time_elastic_predict))
    print(classification_report(y_test, prediction_elastic))

    most_informative_feature_for_class(vect, elastic_clf, 100)
    show_most_informative_features(vect, elastic_clf, 20)
    
    top_a, top_b = get_most_informative_features(vect, elastic_clf, 20)
    top_a_df = pd.DataFrame(top_a)
    top_a_df.columns = ['coef', 'term']
    top_b_df = pd.DataFrame(top_b)
    top_b_df.columns = ['coef', 'term']
    top_a_df.to_csv('../data/major_%s_top20_rep.csv' % t, index=False)
    top_b_df.to_csv('../data/major_%s_top20_dem.csv' % t, index=False)

    joblib.dump(vect, "../models/major_%s_vec_count_cong_23gram.joblib" % t)
    joblib.dump(elastic_clf, "../models/major_%s_cong_clf_elastic.joblib" % t)

    y_test_df = pd.DataFrame(y_test).reset_index(drop=True)
    y_test_df['predicted'] = prediction_elastic
    y_test_df.to_csv('../data/major_%s_test_prediction_party.csv' % t, index=False)

    y_true = y_test.reset_index(drop=True)
    confusion_matrix = ConfusionMatrix(y_true, prediction_elastic)
    print("Confusion matrix:\n%s" % confusion_matrix)

    confusion_matrix.plot()

    from sklearn.metrics import confusion_matrix
    conf = confusion_matrix(y_true, prediction_elastic)
    conf_df = pd.DataFrame(conf)
    conf_df.columns = elastic_clf.classes_
    conf_df.index = elastic_clf.classes_
    conf_df.to_csv('../data/major_%s_test_confusion_matrix_party.csv' % t, index_label="actual \ predicted")
    print conf_df
# Out:
# 13 887
# /opt/venv/local/lib/python2.7/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 13 1055
# 1109
# Removed 28
# Total 1081
# 1081
# 50465576 1081
# Results for Elastic Net
# Training time: 0.077756s; Prediction time: 0.000241s
#              precision    recall  f1-score   support
#
#         100       0.73      0.73      0.73       115
#         200       0.68      0.68      0.68        96
#
# avg / total       0.71      0.71      0.71       211
#
# 100 increas spend 7.11699126637
# 100 food program 7.38724435494
# 100 last sever 7.42453841936
# 100 govern program 7.45539288597
# 100 would say 7.83103381401
# 100 could nt 7.86588189728
# 100 district work 8.05071308447
# 100 make differ 8.33722991377
# 100 year work 8.91346547778
# 100 address issu 9.04520228273
# 	-9.7801	school serv         		9.0452	address issu
# 	-8.2710	work peopl          		8.9135	year work
# 	-8.0409	famili member       		8.3372	make differ
# 	-7.6107	four year           		8.0507	district work
# 	-7.0729	safeti net          		7.8659	could nt
# 	-6.8948	republican major    		7.8310	would say
# 	-6.7521	famili struggl      		7.4554	govern program
# 	-6.7469	hungri children     		7.4245	last sever
# 	-6.6851	past year           		7.3872	food program
# 	-6.6836	year servic         		7.1170	increas spend
# 	-6.6754	republican colleagu 		7.0411	payrol tax
# 	-6.4263	help need           		6.6986	scout america
# 	-6.3221	econom time         		6.4059	back commun
# 	-6.2586	contribut commun    		6.2532	welfar program
# 	-6.1332	everi singl         		5.9607	go beyond
# 	-6.1290	want cut            		5.7616	obama administr
# 	-6.0140	work togeth         		5.7560	tanf program
# 	-5.8694	year later          		5.6710	give back
# 	-5.8216	rhode island        		5.5888	throughout year
# 	-5.7965	join recogn         		5.5620	difficult time
# Confusion matrix:
# Predicted  100  200  __all__
# Actual
# 100         84   31      115
# 200         31   65       96
# __all__    115   96      211
#      100  200
# 100   84   31
# 200   31   65
# 20 10359
# 20 11664
# 17986
# Removed 740
# Total 17246
# 17246
# 84566824 17246
# 95169459 2943
# 101492684 2450
# 47177164 2164
# 27866426 1996
# 89753251 1941
# 120161978 1866
# 42933329 1767
# 92915965 1734
# 110011487 1677
# 96471602 1197
# 91893017 1167
# 90312430 1109
# 99865257 1086
# 93900607 1073
# 89050852 1048
# 29272955 974
# Results for Elastic Net
# Training time: 1.559847s; Prediction time: 0.000618s
#              precision    recall  f1-score   support
#
#         100       0.79      0.85      0.82      1320
#         200       0.79      0.71      0.75      1013
#
# avg / total       0.79      0.79      0.79      2333
#
# 100 cut spend 3.3981539524
# 100 legisl day 3.5442528535
# 100 would say 3.64476873909
# 100 ronald reagan 3.72634406655
# 100 speaker ask unanim 3.74981957889
# 100 senat california 3.82855192495
# 100 texa mr 4.10343081363
# 100 mr speaker 4.18963512043
# 100 job creator 4.65561211283
# 100 detain present 4.68977699474
# 	-6.1850	mr doggett          		4.6898	detain present
# 	-5.3566	civil right         		4.6556	job creator
# 	-5.0436	rhode island        		4.1896	mr speaker
# 	-4.9476	middl class         		4.1034	texa mr
# 	-4.3161	senat proceed       		3.8286	senat california
# 	-4.1555	consent senat proceed		3.7498	speaker ask unanim
# 	-3.8767	republican leadership		3.7263	ronald reagan
# 	-3.8611	citizen unit        		3.6448	would say
# 	-3.7215	tax cut             		3.5443	legisl day
# 	-3.5345	reduc deficit       		3.3982	cut spend
# 	-3.4971	mr levin            		3.3935	print record
# 	-3.4543	announc senat       		3.3902	stimulu bill
# 	-3.3618	mr connolli         		3.3679	follow senat
# 	-3.3331	tea parti           		3.3367	reduc spend
# 	-3.3281	present record      		3.3157	justic depart
# 	-3.2973	pleas join          		3.3131	thought prayer
# 	-3.2931	speaker rise        		3.2760	trillion debt
# 	-3.2727	author meet         		3.2101	pass budget
# 	-3.2322	gentleman massachusett		3.2077	govern program
# 	-3.1691	morn busi           		3.1942	unfund mandat
# Confusion matrix:
# Predicted   100  200  __all__
# Actual
# 100        1126  194     1320
# 200         292  721     1013
# __all__    1418  915     2333
#       100  200
# 100  1126  194
# 200   292  721
# 3 21192
# 3 22409
# 19244
# Removed 572
# Total 18672
# 18672
# 50396601 18672
# 78871300 3230
# 83087080 2490
# 81821445 2183
# 62753329 2064
# 55737419 1982
# 66413832 1914
# 32963634 1770
# 18940765 1687
# 21425164 1666
# 110746876 1650
# 76033129 1604
# 35939401 1481
# 88313694 1453
# 88845310 994
# 75932061 806
# 77576054 793
# 74239487 783
# 74613501 750
# 82694569 740
# 80167724 732
# 72423110 727
# 28876989 675
# Results for Elastic Net
# Training time: 2.025469s; Prediction time: 0.000762s
#              precision    recall  f1-score   support
#
#         100       0.75      0.82      0.78      2583
#         200       0.72      0.62      0.67      1899
#
# avg / total       0.74      0.74      0.73      4482
#
# 100 rise opposit motion 3.19381243853
# 100 mr dreier 3.24436644431
# 100 move committe 3.43017227662
# 100 save medicar 3.49738332005
# 100 enter colloquy 3.51100655347
# 100 gentlewoman wyom 3.63600703583
# 100 care law 4.06349305995
# 100 health care law 4.17470713632
# 100 feder govern 4.5122000879
# 100 idaho recogn 5.10433689516
# 	-5.2235	insur compani       		5.1043	idaho recogn
# 	-4.3858	tax cut             		4.5122	feder govern
# 	-3.9262	end medicar         		4.1747	health care law
# 	-3.8441	minut gentlewoman   		4.0635	care law
# 	-3.6834	tax break           		3.6360	gentlewoman wyom
# 	-3.5532	republican major    		3.5110	enter colloquy
# 	-3.5053	second read         		3.4974	save medicar
# 	-3.4961	senat proceed       		3.4302	move committe
# 	-3.3914	indiana recogn      		3.2444	mr dreier
# 	-3.2790	gentleman indiana recogn		3.1938	rise opposit motion
# 	-3.2445	middl class         		3.1677	repeal obamacar
# 	-3.0555	seconddegre amend   		3.1352	american peopl
# 	-2.9946	republican budget   		3.0210	new member
# 	-2.9795	rhode island        		3.0130	speaker rise opposit
# 	-2.9760	without object order		2.8981	wyom recogn
# 	-2.9707	clotur motion       		2.8159	across state
# 	-2.9119	democrat caucu      		2.7750	class act
# 	-2.8921	current form        		2.7165	texa recogn
# 	-2.8202	preexist condit     		2.6642	gentleman arkansa
# 	-2.8046	massachusett recogn 		2.6554	let know
# Confusion matrix:
# Predicted   100   200  __all__
# Actual
# 100        2129   454     2583
# 200         720  1179     1899
# __all__    2849  1633     4482
#       100   200
# 100  2129   454
# 200   720  1179
# 18 1368
# 18 1691
# 2239
# Removed 65
# Total 2174
# 2174
# 37848665 2174
# Results for Elastic Net
# Training time: 0.148812s; Prediction time: 0.000297s
#              precision    recall  f1-score   support
#
#         100       0.77      0.70      0.73       175
#         200       0.71      0.77      0.74       164
#
# avg / total       0.74      0.74      0.74       339
#
# 100 gentleman california mr 5.05974178514
# 100 good friend 5.60623386259
# 100 export opportun 5.69267686282
# 100 present would 5.91163632026
# 100 go allow 6.27275644783
# 100 reserv gentleman 6.37313822017
# 100 move strike 6.61669875665
# 100 winner loser 6.71820074789
# 100 white hous 9.10745210545
# 100 senat ohio 9.56929982487
# 	-6.6992	gentleman indiana   		9.5693	senat ohio
# 	-5.7309	civil right         		9.1075	white hous
# 	-5.7038	trade polici        		6.7182	winner loser
# 	-5.4472	north carolina      		6.6167	move strike
# 	-5.2126	benefit american    		6.3731	reserv gentleman
# 	-5.1952	fair trade          		6.2728	go allow
# 	-5.1586	american manufactur 		5.9116	present would
# 	-5.1430	labor right         		5.6927	export opportun
# 	-5.0847	lost job            		5.6062	good friend
# 	-5.0790	author meet         		5.0597	gentleman california mr
# 	-4.9669	trade deal          		5.0563	freetrad agreement
# 	-4.9535	bill would          		5.0228	govern spend
# 	-4.9470	exportimport bank   		4.8854	train program
# 	-4.8834	trade deficit       		4.8398	friend side
# 	-4.8797	american peopl      		4.7109	senat schumer
# 	-4.7904	join us             		4.6854	busi farmer
# 	-4.7694	lower tariff        		4.6344	us industri
# 	-4.7393	wo nt               		4.6028	gentleman florida
# 	-4.6662	throughout countri  		4.5688	spend program
# 	-4.6311	gentleman washington		4.5415	creat environ
# Confusion matrix:
# Predicted  100  200  __all__
# Actual
# 100        123   52      175
# 200         37  127      164
# __all__    160  179      339
#      100  200
# 100  123   52
# 200   37  127
# 19 2137
# 19 2742
# 3804
# Removed 129
# Total 3675
# 3675
# 93148912 3675
# 90238934 306
# 22676118 234
# 31116875 222
# 65992913 213
# 117711352 205
# 59187817 179
# 75040710 166
# 99059793 119
# 100101135 115
# 65609477 103
# Results for Elastic Net
# Training time: 0.264349s; Prediction time: 0.000374s
#              precision    recall  f1-score   support
#
#         100       0.74      0.79      0.76       326
#         200       0.66      0.61      0.63       223
#
# avg / total       0.71      0.71      0.71       549
#
# 100 re talk 4.8879770842
# 100 cote divoir 4.95784598141
# 100 opposit leader 5.01115783547
# 100 thank gentleladi 5.18386441657
# 100 mr speaker 5.36420522497
# 100 foreign countri 5.43029135744
# 100 world countri 5.56086828205
# 100 war terror 5.62439330875
# 100 american citizen 6.58565416257
# 100 muslim brotherhood 6.83290275081
# 	-5.8531	turkish govern      		6.8329	muslim brotherhood
# 	-5.6421	mr speaker rise     		6.5857	american citizen
# 	-5.6362	human be            		5.6244	war terror
# 	-5.6069	close relationship  		5.5609	world countri
# 	-5.4088	rollcal vote        		5.4303	foreign countri
# 	-5.0964	innoc peopl         		5.3642	mr speaker
# 	-5.0293	million peopl       		5.1839	thank gentleladi
# 	-4.5735	women children      		5.0112	opposit leader
# 	-4.5683	speaker rise        		4.9578	cote divoir
# 	-4.5642	relationship unit   		4.8880	re talk
# 	-4.5642	relationship unit state		4.8583	kill american
# 	-4.5024	el salvador         		4.6785	wish best
# 	-4.4761	mr deutch           		4.6677	israel enemi
# 	-4.4275	freedom express     		4.6257	opposit group
# 	-4.4224	committe foreign relat		4.5958	happi yield
# 	-4.3753	like congratul      		4.4655	without trial
# 	-4.3658	peac secur          		4.4407	clinton secretari
# 	-4.3536	role model          		4.4277	govern iran
# 	-4.3126	colleagu pleas      		4.4249	us countri
# 	-4.2417	justic system       		4.4102	trade relat
# Confusion matrix:
# Predicted  100  200  __all__
# Actual
# 100        256   70      326
# 200         88  135      223
# __all__    344  205      549
#      100  200
# 100  256   70
# 200   88  135
# 16 9139
# 16 10515
# 16526
# Removed 453
# Total 16073
# 16073
# 87551573 16073
