# %% [markdown]
# ### Original
#
# The data are at: opt/data/bills-out.csv
#
# We will train 3 classifiers, likely SVM as number of categories is a lot:
#
# 1. predict 'Minor': column labeled 'minor'
# 2. predict 'Major': column labeled 'major'
# 3. predict only categories where topic_code.csv (also in opt/data) says include ==1 (I will update this soon.)
#
#
# How?
# 1. Tokenize bill text
# 2. Break into 5000 word chunks per bill
# 3. Use SVM to predict --- cross-validate to tune
# 4. Show classification success and print out top coefficients for each category so that we can verify that the model makes sense
# 5. Predict congressional speech --- it is in opt/cong (or you can download via capitolwords API based on the script you wrote, we want to predict for each congress.)
#    Predict each category. If you have 9 categories, you will get 9 columns.
#
# ### Recap
#
# 1. Let us again remove Roberts rules bigrams/trigrams again
# 2. With just 10k tokens, I think we are selling ourselves short. Let us remove only bigrams/trigrams that are in 20 documents or less.
# 3. Let us try GradientBoostedClassifier also
# 4. Let us not chunk in 5k as bills seem to be ok length except for 5 or so bills which have less than 1000 characters
#
# What to predict?
# 1. Major topics
# 2. Minor topics: but take out all with the label 'other' or 'general'. To find out the topic codes, see topic_code.csv. We can also take out minor topics that don't have more than 10 bills.
# 5. The third model will only include minor topics which in topic_code.csv column topic_1 ==1 And again we want minor topics that don't have more than 10 bills
#
# Next steps after the models:
# 1. Output top 20 bigrams/trigrams for each topic where column_name = topic_label (from topic_code.csv) for each model

# %%
import pandas as pd
import numpy as np
import time

# %% [markdown]
# ## Read Bills dataset (cleaned version)

# %%
df = pd.read_csv('../data/bills-out-clean.csv.gz', nrows=10)
df.columns
# Out:
# Index([u'uid', u'Major', u'Minor', u'clean_text'], dtype='object')

# %%
df = pd.read_csv('../data/bills-out-clean.csv.gz', usecols=['Major', 'Minor', 'clean_text'])
df
# Out:
#        Major  Minor                                         clean_text
# 0         20   2012  congression bill 103th congress us govern prin...
# 1          3    300  congression bill 103th congress us govern prin...
# 2         15   1520  congression bill 103th congress us govern prin...
# 3         20   2000  congression bill 103th congress us govern prin...
# 4         15   1522  congression bill 103th congress us govern prin...
# 5          1    107  congression bill 103th congress us govern prin...
# 6         14   1401  congression bill 103th congress us govern prin...
# 7          1    107  congression bill 103th congress us govern prin...
# 8         14   1406  congression bill 103th congress us govern prin...
# 9          3    331  congression bill 103th congress us govern prin...
# 10        20   2012  congression bill 103th congress us govern prin...
# 11         3    301  congression bill 103th congress us govern prin...
# 12        18   1806  congression bill 103th congress us govern prin...
# 13         2    207  congression bill 103th congress us govern prin...
# 14        15   1504  congression bill 103th congress us govern prin...
# 15         6    601  congression bill 103th congress us govern prin...
# 16         3    302  congression bill 103th congress us govern prin...
# 17        16   1609  congression bill 103th congress us govern prin...
# 18        13   1303  congression bill 103th congress us govern prin...
# 19        21   2101  congression bill 103th congress us govern prin...
# 20        21   2103  congression bill 103th congress us govern prin...
# 21         2    201  congression bill 103th congress us govern prin...
# 22        14   1406  congression bill 103th congress us govern prin...
# 23         5    501  congression bill 103th congress us govern prin...
# 24        16   1609  congression bill 103th congress us govern prin...
# 25        20   2004  congression bill 103th congress us govern prin...
# 26        20   2012  congression bill 103th congress us govern prin...
# 27         3    325  congression bill 103th congress us govern prin...
# 28         1    107  congression bill 103th congress us govern prin...
# 29        15   1504  congression bill 103th congress us govern prin...
# ...      ...    ...                                                ...
# 25325      1    104  congression bill 112th congress us govern prin...
# 25326      5    502  congression bill 112th congress us govern prin...
# 25327     20   2006  congression bill 112th congress us govern prin...
# 25328      3    321  congression bill 112th congress us govern prin...
# 25329      3    321  congression bill 112th congress us govern prin...
# 25330     10   1003  congression bill 112th congress us govern prin...
# 25331     20   2012  congression bill 112th congress us govern prin...
# 25332     21   2103  congression bill 112th congress us govern prin...
# 25333     12   1210  congression bill 112th congress us govern prin...
# 25334      3    321  congression bill 112th congress us govern prin...
# 25335     17   1701  congression bill 112th congress us govern prin...
# 25336     12   1211  congression bill 112th congress us govern prin...
# 25337     20   2001  congression bill 112th congress us govern prin...
# 25338     15   1525  congression bill 112th congress us govern prin...
# 25339      7    711  congression bill 112th congress us govern prin...
# 25340     12   1210  congression bill 112th congress us govern prin...
# 25341     15   1521  congression bill 112th congress us govern prin...
# 25342      5    530  congression bill 112th congress us govern prin...
# 25343      6    602  congression bill 112th congress us govern prin...
# 25344      1    104  congression bill 112th congress us govern prin...
# 25345     13   1303  congression bill 112th congress us govern prin...
# 25346     15   1521  congression bill 112th congress us govern prin...
# 25347     15   1523  congression bill 112th congress us govern prin...
# 25348      7    710  congression bill 112th congress us govern prin...
# 25349     20   2006  congression bill 112th congress us govern prin...
# 25350      1    107  congression bill 112th congress us govern prin...
# 25351     15   1502  congression bill 112th congress us govern prin...
# 25352     13   1303  congression bill 112th congress us govern prin...
# 25353     21   2101  congression bill 112th congress us govern prin...
# 25354      7    704  congression bill 112th congress us govern prin...
#
# [25355 rows x 3 columns]

# %% [markdown]
# ## Split long bill to smaller chunk (5000 words)

# %%
import re
import textwrap

def insert_chars_split_marker(text, cc=2500):
    # FIXME: text still has number
    text = re.sub('\d+', '', text)
    out = '|'.join(textwrap.wrap(text, cc))
    return out

def insert_words_split_marker(text, wc=500):
    text = re.sub('\d+', '', text)
    words = text.split()
    out = ''
    for i, w in enumerate(words):
        if i != 0 and i % wc == 0:
            out += '|' + w
        else:
            out += ' ' + w
    return out

# %%
if False:
    df['clean_text'] = df['clean_text'].apply(lambda c: insert_words_split_marker(c, 5000))

# %%
if False:
    s = df['clean_text'].str.split('|', expand=True).stack()
    i = s.index.get_level_values(0)
    new_df = df.loc[i].copy()
    new_df['chunk'] = s.index.get_level_values(1)
    new_df['clean_text'] = s.values
    df = new_df
    df

# %% [markdown]
# ## Vectorize

# %%
import nltk
from nltk import word_tokenize          
from nltk.stem.porter import PorterStemmer
import re
import string

stemmer = PorterStemmer()
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

#def tokenize(text):
#    tokens = nltk.word_tokenize(text)
#    stems = stem_tokens(tokens, stemmer)
#    return stems

def tokenize(text):
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    return stems

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.cross_validation import train_test_split

# %%
with open('../roberts_rules/all_text.txt', 'rt') as f:
    text = f.read()
text = text.decode('ascii', 'ignore')
text = re.sub(r'\d+', '', text)

vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3)) 
vect.fit([text])
roberts_rules = set(vect.get_feature_names())

# %%
#vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3), min_df=0.01)
#vect = CountVectorizer(ngram_range=(2, 3), min_df=0.01) 
#vect = CountVectorizer(ngram_range=(2, 3)) 
vect = CountVectorizer(ngram_range=(2, 3), min_df=20) 
vect.fit(df.clean_text)
# Out:
# CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=20,
#         ngram_range=(2, 3), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
len(vect.get_feature_names())
# Out:
# 247335

# %%
vocab = []
i = 0
for a in vect.vocabulary_:
    if a not in roberts_rules:
        vocab.append(a)
    else:
        #print a
        i += 1
print("Removed {0:d}".format(i))
print("Total {0:d}".format(len(vocab)))
# Out:
# Removed 2653
# Total 244682

# %%
ng_df = pd.DataFrame(vocab)
ng_df.columns = ['ngram']
ng_df
# Out:
#                             ngram
# 0                   agenc sponsor
# 1                  payment method
# 2             shall determin take
# 3               shall submit year
# 4                  period commiss
# 5                     improv awar
# 6               gener rulesubject
# 7               amount 10 percent
# 8        amount specifi paragraph
# 9                      day includ
# 10               assist distribut
# 11              fund insert feder
# 12              state code insert
# 13                  involv import
# 14                 use 75 percent
# 15                 center increas
# 16             nation imageri map
# 17               safeti construct
# 18          wilder design section
# 19           includ inform requir
# 20               individu specifi
# 21           presid act administr
# 22                   evalu select
# 23                disclos subsect
# 24        provid statement submit
# 25                  amend titl 38
# 26           subject civil action
# 27         assist individu obtain
# 28          provid furnish servic
# 29                   seq individu
# ...                           ...
# 244652              order commiss
# 244653   sentenc strike secretari
# 244654            employ otherwis
# 244655               titl 25 code
# 244656                 loss human
# 244657          develop voluntari
# 244658        compani mean person
# 244659            convey otherwis
# 244660                    bayh mr
# 244661                applic issu
# 244662                 activ part
# 244663            offer sale sell
# 244664   messag transmit congress
# 244665                 facil less
# 244666           state sec author
# 244667             job growth tax
# 244668          read followsdelet
# 244669      flood control project
# 244670          tom davi virginia
# 244671          compens paragraph
# 244672       equal product applic
# 244673                  ii result
# 244674         1861u social secur
# 244675               exceed 75000
# 244676    basi determin secretari
# 244677           appli amend made
# 244678              measur assess
# 244679               secur social
# 244680  deleg authorityani member
# 244681             stimul develop
#
# [244682 rows x 1 columns]

# %%
#ng_df.to_csv('../data/bills-23gram.csv', index=False)

# %%
def most_informative_feature_for_class(vectorizer, classifier, classlabel, n=10):
    labelid = list(classifier.classes_).index(classlabel)
    feature_names = vectorizer.get_feature_names()
    topn = sorted(zip(classifier.coef_[labelid], feature_names))[-n:]

    for coef, feat in topn:
        print classlabel, feat, coef

def most_informative_feature_for_class_svm(vectorizer, classifier,  n=10):
    labelid = 3 # this is the coef we're interested in. 
    feature_names = vectorizer.get_feature_names()
    svm_coef = classifier.coef_.toarray() 
    topn = sorted(zip(svm_coef[labelid], feature_names))[-n:]

    for coef, feat in topn:
        print feat, coef

def print_top10(vectorizer, clf, class_labels):
    """Prints features with the highest coefficient values, per class"""
    feature_names = vectorizer.get_feature_names()
    for i, class_label in enumerate(class_labels):
        top10 = np.argsort(clf.coef_[i])[-10:]
        print("%s: %s" % (class_label,
              " | ".join(feature_names[j] for j in top10)))

def get_top_features(vectorizer, clf, class_labels, n=20):
    """Prints features with the highest coefficient values, per class"""
    feature_names = vectorizer.get_feature_names()
    top_features = {}
    for i, class_label in enumerate(class_labels):
        topN = np.argsort(clf.coef_[i])[-n:]
        top_features[class_label] = [feature_names[j] for j in topN][::-1]
    return top_features

# %% [markdown]
# ## Model (Major)

# %%
df.groupby('Major').agg({'Major': 'count'})
# Out:
#        Major
# Major
# 1       1021
# 2        539
# 3       2869
# 4        558
# 5       1429
# 6       1153
# 7       1228
# 8        979
# 10       973
# 12      1570
# 13       650
# 14       478
# 15      1687
# 16      1481
# 17       514
# 18      2395
# 19       732
# 20      2390
# 21      2308
# 99       401

# %%
X = df.clean_text
y = df.Major

X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
#vect = CountVectorizer(ngram_range=(2, 3), min_df=20, vocabulary=vocab)
vect = CountVectorizer(ngram_range=(2, 3), min_df=10, max_df=5000, vocabulary=vocab)

# %%
X_train = vect.transform(X_train)
transformer = TfidfTransformer()
X_train = transformer.fit_transform(X_train)

# %%
X_test = vect.transform(X_test)
transformer = TfidfTransformer()
X_test = transformer.fit_transform(X_test)

# %%
# Perform classification with SVM, kernel=linear
classifier_liblinear = svm.LinearSVC()
t0 = time.time()
classifier_liblinear.fit(X_train, y_train)
t1 = time.time()
prediction_liblinear = classifier_liblinear.predict(X_test)
t2 = time.time()
time_liblinear_train = t1-t0
time_liblinear_predict = t2-t1

print("Results for LinearSVC()")
print("Training time: %fs; Prediction time: %fs" % (time_liblinear_train, time_liblinear_predict))
print(classification_report(y_test, prediction_liblinear))
# Out:
# Results for LinearSVC()
# Training time: 39.974688s; Prediction time: 0.319057s
#              precision    recall  f1-score   support
#
#           1       0.63      0.67      0.65       204
#           2       0.76      0.50      0.60       108
#           3       0.85      0.91      0.88       574
#           4       0.88      0.76      0.81       112
#           5       0.77      0.77      0.77       286
#           6       0.88      0.83      0.85       231
#           7       0.81      0.77      0.79       246
#           8       0.84      0.85      0.84       196
#          10       0.82      0.85      0.83       195
#          12       0.76      0.76      0.76       314
#          13       0.79      0.73      0.76       130
#          14       0.71      0.69      0.70        96
#          15       0.74      0.74      0.74       337
#          16       0.73      0.75      0.74       296
#          17       0.71      0.70      0.71       103
#          18       0.94      0.94      0.94       479
#          19       0.68      0.70      0.69       146
#          20       0.76      0.77      0.76       478
#          21       0.85      0.88      0.86       462
#          99       0.88      0.84      0.86        80
#
# avg / total       0.80      0.80      0.80      5073

# %%
most_informative_feature_for_class(vect, classifier_liblinear, 99)
#most_informative_feature_for_class_svm(vect, classifier_linear)
# Out:
# 99 committe judiciari 0.798276270577
# 99 provid relief 0.804124337037
# 99 refer committe judiciari 0.864308227234
# 99 author request 0.916199746916
# 99 emerg relief 0.952969615349
# 99 mean bill provid 1.0280892288
# 99 honolulu hawaii 1.12010521615
# 99 act relief 1.34671244907
# 99 judiciari bill relief 2.50058938693
# 99 bill relief 3.76298655211

# %%
print_top10(vect, classifier_liblinear, classifier_liblinear.classes_)
# Out:
# 1: busi interest | meal entertain | penalti relief | budget year | deficit reduct | mileag rate | capit gain | gift tax | tax system | public debt
# 2: religi freedom | civil right | privaci act | grammleachbliley act | drug test | vote right | person inform | sexual orient | genet inform | perform abort
# 3: health insur | medic malpractic | titl xviii social | medicar program | public health | amend titl xviii | titl xviii | health care | medic care | prescript drug
# 4: incom averag | farm incom | agricultur product | food safeti | genet engin | amend agricultur | anim drug | refer committe agricultur | committe agricultur | secretari agricultur
# 5: labor organ | individu retir | illeg alien | amend immigr nation | nation act | child care | immigr nation act | amend immigr | immigr nation | unemploy compens
# 6: depart educ | qualifi tuition | public school | educ loan | educ act | elementari secondari | higher educ | educ assist | secretari educ | student loan
# 7: hazard wast | hazard materi | environment protect agenc | endang speci | protect agenc | migratori bird | drink water | administr shall | environment protect | solid wast
# 8: clean energi | energi effici | energi properti | natur ga | electr energi | energi polici | depart energi | secretari energi | oil ga | crude oil
# 10: transport system | public transport | highway trust | rail passeng | feder aviat | highway vehicl | air carrier | transport infrastructur | air transport | secretari transport
# 12: domest violenc | money launder | adopt expens | firearm ammunit | child support | death penalti | feder prison | refer committe judiciari | committe judiciari | foster care
# 13: deliveri mail | 42 usc | individu disabl | boy scout | home energi | older individu | nutrit act | food stamp | social servic | social secur
# 14: commun develop | mortgag bond | renew commun | princip resid | invest save | rural develop | nation hous act | empower zone | hous credit | hous act
# 15: credit card | product safeti | profession sport | flood insur | disast relief | insur compani | secur exchang | antitrust law | 15 usc | small busi
# 16: secretari navi | closur realign | air forc | refer committe arm | disabl veteran | arm servic bill | nation guard | homeland secur | depart defens | arm forc
# 17: satellit servic | news inform | 47 usc | commun act 1934 | feder commun | feder commun commiss | commerci space | commun commiss | commun act | motion pictur
# 18: 19 usc | trade deficit | harmon tariff schedul | harmon tariff | financ bill provid | trade act 1974 | hong kong | suspens duti | exportimport bank | trade agreement
# 19: depart state | relat bill | panama canal | secretari state | develop countri | peac corp | refer committe foreign | human right | 22 usc | unit nation
# 20: postal servic | independ counsel | polit parti | feder elect | refer committe hous | feder employe | administr bill | public build | joint committe | district columbia
# 21: puerto rico | indian tribal | nation histor | committe resourc | refer committe resourc | indian reserv | 25 usc | american samoa | resourc bill | indian tribe
# 99: committe judiciari | provid relief | refer committe judiciari | author request | emerg relief | mean bill provid | honolulu hawaii | act relief | judiciari bill relief | bill relief

# %%
topics_df = pd.read_csv('../data/topic_code.csv')

# %%
top_features = get_top_features(vect, classifier_liblinear, classifier_liblinear.classes_)
top_features_df = pd.DataFrame(top_features)
columns = []
for c in top_features_df.columns:
    cname = topics_df[topics_df.code == c].topic.values[0]
    columns.append(cname)
top_features_df.columns = columns
#top_features_df.to_csv('../data/major_bills_top20.csv', index=False)
top_features_df
# Out:
#         Macroeconomics Civil Rights, Minority Issues, and Civil Liberties  \
# 0          public debt                                      perform abort
# 1           tax system                                       genet inform
# 2             gift tax                                      sexual orient
# 3           capit gain                                      person inform
# 4          mileag rate                                         vote right
# 5       deficit reduct                                          drug test
# 6          budget year                               grammleachbliley act
# 7       penalti relief                                        privaci act
# 8       meal entertain                                        civil right
# 9        busi interest                                     religi freedom
# 10       preciou metal                                     discrimin basi
# 11           incom tax                                          fair hous
# 12         minimum tax                                    sexual explicit
# 13          debt limit                                       fire station
# 14           feder tax                                         girl women
# 15           save bond                                        vote system
# 16  deduct state local                                        first amend
# 17     depreci certain                                        free speech
# 18       charit deduct                                       abort servic
# 19           busi meal                                    civil right act
#
#                   Health                Agriculture  \
# 0         prescript drug       secretari agricultur
# 1             medic care        committe agricultur
# 2            health care  refer committe agricultur
# 3             titl xviii                  anim drug
# 4       amend titl xviii           amend agricultur
# 5          public health                genet engin
# 6        medicar program                food safeti
# 7      titl xviii social         agricultur product
# 8       medic malpractic                 farm incom
# 9           health insur               incom averag
# 10          xviii social             farmer rancher
# 11    xviii social secur          livestock poultri
# 12          medic assist               meat poultri
# 13         health servic                 crop insur
# 14           medic facil             prepar preserv
# 15       tobacco product   committe agricultur bill
# 16           medic devic         valuead agricultur
# 17           organ donat              dairi product
# 18           health plan            agricultur bill
# 19  public health servic              farmer cooper
#
#    Labor, Employment, and Immigration             Education  \
# 0                    unemploy compens          student loan
# 1                       immigr nation        secretari educ
# 2                        amend immigr           educ assist
# 3                   immigr nation act           higher educ
# 4                          child care  elementari secondari
# 5                          nation act              educ act
# 6                 amend immigr nation             educ loan
# 7                         illeg alien         public school
# 8                      individu retir       qualifi tuition
# 9                         labor organ           depart educ
# 10                        depend care        lifelong learn
# 11                       pension plan         educ act 1965
# 12                          plan year             educ save
# 13                     special immigr               gi bill
# 14                          wage paid    montgomeri gi bill
# 15                             29 usc          certain educ
# 16                      committe educ           educ expens
# 17                       crimin alien         montgomeri gi
# 18                        numer limit                20 usc
# 19                     employe employ            educ organ
#
#                   Environment              Energy  \
# 0                  solid wast           crude oil
# 1         environment protect              oil ga
# 2             administr shall    secretari energi
# 3                 drink water       depart energi
# 4              migratori bird       energi polici
# 5               protect agenc       electr energi
# 6                endang speci            natur ga
# 7   environment protect agenc     energi properti
# 8               hazard materi       energi effici
# 9                 hazard wast        clean energi
# 10                  clean air       pipelin facil
# 11              chesapeak bay         feder power
# 12                    air act     feder power act
# 13              clean air act           home heat
# 14         nation environment        renew energi
# 15            qualifi conserv           fuel cell
# 16                conserv act      energi conserv
# 17                wast dispos  regulatori commiss
# 18                 coral reef       electr produc
# 19            carbon sequestr      qualifi energi
#
#                       Transportation Law, Crime, and Family Issues  \
# 0                secretari transport                   foster care
# 1                      air transport            committe judiciari
# 2            transport infrastructur      refer committe judiciari
# 3                        air carrier                  feder prison
# 4                     highway vehicl                 death penalti
# 5                        feder aviat                 child support
# 6                       rail passeng               firearm ammunit
# 7                      highway trust                  adopt expens
# 8                   public transport                 money launder
# 9                   transport system                domest violenc
# 10                highway trust fund                    law enforc
# 11                      rail carrier                  credit adopt
# 12                           titl 49                    child abus
# 13                       heavi truck                   feder court
# 14                  railroad carrier                judiciari bill
# 15                        cruis ship       committe judiciari bill
# 16          refer committe transport                  adopt assist
# 17                     motor carrier                   drug offens
# 18                       coast guard                 depart justic
# 19  committe transport infrastructur                   volunt fire
#
#           Social Welfare Community Development and Housing Issues  \
# 0           social secur                                 hous act
# 1          social servic                              hous credit
# 2             food stamp                             empower zone
# 3             nutrit act                          nation hous act
# 4         older individu                            rural develop
# 5            home energi                              invest save
# 6              boy scout                            princip resid
# 7        individu disabl                             renew commun
# 8                 42 usc                             mortgag bond
# 9          deliveri mail                           commun develop
# 10           food assist                              afford hous
# 11        older american                            militari hous
# 12             ii social                            mortgag insur
# 13         commun servic                          veteran mortgag
# 14         secur benefit                                hous loan
# 15  social secur benefit                               hous agenc
# 16       ii social secur                                home loan
# 17          school lunch                  metropolitan washington
# 18    home energi assist                             hous project
# 19         amend titl ii                          mortgag payment
#
#    Banking, Finance, and Domestic Commerce                 Defense  \
# 0                               small busi                arm forc
# 1                                   15 usc           depart defens
# 2                            antitrust law          homeland secur
# 3                            secur exchang            nation guard
# 4                            insur compani         arm servic bill
# 5                            disast relief          disabl veteran
# 6                              flood insur      refer committe arm
# 7                         profession sport                air forc
# 8                           product safeti          closur realign
# 9                              credit card          secretari navi
# 10                                 titl 17          ballist missil
# 11                            stock option            border secur
# 12                            credit union  refer committe veteran
# 13                        terrorist attack                 titl 10
# 14                           athlet associ           threat reduct
# 15                           financi crime            committe arm
# 16                          financi servic              arm servic
# 17                          consum protect     committe arm servic
# 18                            home program           nation defens
# 19                          product averag      homeland secur act
#
#    Space, Science, Technology and Communications          Foreign Trade  \
# 0                                  motion pictur        trade agreement
# 1                                     commun act      exportimport bank
# 2                                 commun commiss           suspens duti
# 3                                 commerci space              hong kong
# 4                           feder commun commiss         trade act 1974
# 5                                   feder commun     financ bill provid
# 6                                commun act 1934          harmon tariff
# 7                                         47 usc  harmon tariff schedul
# 8                                    news inform          trade deficit
# 9                                satellit servic                 19 usc
# 10                              public broadcast       countervail duti
# 11                             televis broadcast               lo angel
# 12                                      act 1934    tariff schedul unit
# 13                                 ocean coastal           foreign sale
# 14                                   author user        committe financ
# 15                               telephon servic        prohibit import
# 16                                  radio servic       export administr
# 17                             telecommun servic            domest fuel
# 18                         nation aeronaut space             free trade
# 19                                broadcast cuba           schedul unit
#
#    International Affairs and Foreign Aid  Government Operations  \
# 0                            unit nation      district columbia
# 1                                 22 usc         joint committe
# 2                            human right           public build
# 3                 refer committe foreign         administr bill
# 4                              peac corp          feder employe
# 5                        develop countri    refer committe hous
# 6                        secretari state            feder elect
# 7                           panama canal            polit parti
# 8                             relat bill       independ counsel
# 9                           depart state          postal servic
# 10                        foreign assist          former presid
# 11                          baltic state              titl unit
# 12                   foreign affair bill           postag stamp
# 13                      committe foreign             land grant
# 14                        intern fisheri              item veto
# 15                               12 2010     member hous repres
# 16                            januari 12        titl unit state
# 17                     intern relat bill            lobbi activ
# 18                        olymp committe       librari congress
# 19                      reconstruct iraq  refer committe govern
#
#    Public Lands and Water Management Other, Miscellaneous, and Human Interest
# 0                       indian tribe                              bill relief
# 1                       resourc bill                    judiciari bill relief
# 2                     american samoa                               act relief
# 3                             25 usc                          honolulu hawaii
# 4                      indian reserv                         mean bill provid
# 5             refer committe resourc                             emerg relief
# 6                   committe resourc                           author request
# 7                      nation histor                 refer committe judiciari
# 8                      indian tribal                            provid relief
# 9                        puerto rico                       committe judiciari
# 10                     natur resourc                            respect award
# 11                       nation park                         foreign registri
# 12                     nation forest                            brigadi gener
# 13                     nation memori                           household good
# 14                     nation museum                           drawback claim
# 15             committe resourc bill                                shall pay
# 16                        corp engin                  committe judiciari bill
# 17                    nativ hawaiian                           judiciari bill
# 18                       river basin                            place foreign
# 19         direct secretari interior                        award congression

# %%
from sklearn.externals import joblib

#joblib.dump(vect, "../models/vec_count_bills_23gram.joblib")
#joblib.dump(classifier_liblinear, "../models/major_bills_clf_liblinear.joblib")

# %% [markdown]
# ## Try SGDClassifier

# %%
if False:
    from sklearn.linear_model import SGDClassifier

    elastic_clf = SGDClassifier(loss='log', alpha=.00002, n_iter=200, penalty="elasticnet")
    t0 = time.time()
    elastic_clf.fit(X_train, y_train)
    t1 = time.time()
    prediction_elastic = elastic_clf.predict(X_test)
    t2 = time.time()
    time_elastic_train = t1-t0
    time_elastic_predict = t2-t1

    print("Results for Elastic Net")
    print("Training time: %fs; Prediction time: %fs" % (time_elastic_train, time_elastic_predict))
    print(classification_report(y_test, prediction_elastic))

# %%
if False:
    most_informative_feature_for_class(vect, elastic_clf, 99)

# %%
if False:
    print_top10(vect,  elastic_clf,  elastic_clf.classes_)

# %% [markdown]
# ## Minor Model

# %% [markdown]
# #### Was removed!!!

# %% [markdown]
# ## Model (topic_1 == 1)

# %%
selected_topics = topics_df[topics_df.topic_1 == 1].code.unique()

# %%
selected_topics
# Out:
# array([ 101,  103,  105,  107,  201,  202,  206,  207,  209,  301,  302,
#         323,  324,  331,  332,  333,  335,  403,  404,  501,  502,  503,
#         504,  505,  508,  529,  601,  603,  607,  609,  701,  703,  704,
#         705,  709,  710,  801,  802,  803,  806,  807,  900, 1002, 1003,
#        1005, 1006, 1007, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209,
#        1301, 1302, 1303, 1304, 1401, 1501, 1502, 1504, 1507, 1521, 1522,
#        1523, 1525, 1602, 1603, 1605, 1609, 1610, 1612, 1615, 1701, 1706,
#        1707, 1709, 1802, 1807, 1901, 1915, 1925, 1926, 1927, 2002, 2003,
#        2006, 2010, 2011, 2012, 2013, 2101, 2102])

# %%
X = df[df.Minor.isin(selected_topics)].clean_text
y = df[df.Minor.isin(selected_topics)].Minor

X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-c6758801757e> in <module>()
#       2 y = df[df.Minor.isin(selected_topics)].Minor
#       3
# ----> 4 X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)
#
# /opt/venv/local/lib/python2.7/site-packages/sklearn/cross_validation.pyc in train_test_split(*arrays, **options)
#    1908         cv = StratifiedShuffleSplit(stratify, test_size=test_size,
#    1909                                     train_size=train_size,
# -> 1910                                     random_state=random_state)
#    1911     else:
#    1912         n_samples = _num_samples(arrays[0])
#
# /opt/venv/local/lib/python2.7/site-packages/sklearn/cross_validation.pyc in __init__(self, y, n_iter, test_size, train_size, random_state)
#     960
#     961         if np.min(bincount(self.y_indices)) < 2:
# --> 962             raise ValueError("The least populated class in y has only 1"
#     963                              " member, which is too few. The minimum"
#     964                              " number of labels for any class cannot"
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of labels for any class cannot be less than 2.

# %%
X_train = vect.transform(X_train)
transformer = TfidfTransformer()
X_train = transformer.fit_transform(X_train)

# %%
X_test = vect.transform(X_test)
transformer = TfidfTransformer()
X_test = transformer.fit_transform(X_test)

# %%
# Perform classification with SVM, kernel=linear
classifier_liblinear = svm.LinearSVC()
t0 = time.time()
classifier_liblinear.fit(X_train, y_train)
t1 = time.time()
prediction_liblinear = classifier_liblinear.predict(X_test)
t2 = time.time()
time_liblinear_train = t1-t0
time_liblinear_predict = t2-t1

print("Results for LinearSVC()")
print("Training time: %fs; Prediction time: %fs" % (time_liblinear_train, time_liblinear_predict))
print(classification_report(y_test, prediction_liblinear))

# %%
most_informative_feature_for_class(vect, classifier_liblinear, 501)

# %%
print_top10(vect, classifier_liblinear, classifier_liblinear.classes_)

# %%
top_features = get_top_features(vect, classifier_liblinear, classifier_liblinear.classes_)
top_features_df = pd.DataFrame(top_features)
columns = []
for c in top_features_df.columns:
    cname = topics_df[topics_df.code == c].topic.values[0]
    columns.append(cname)
top_features_df.columns = columns
#top_features_df.to_csv('../data/topic_1_bills_top20.csv', index=False)
top_features_df

# %%
from sklearn.externals import joblib

#joblib.dump(vect, "../models/vec_count_bills_23gram.joblib")
#joblib.dump(classifier_liblinear, "../models/topic_1_bills_clf_liblinear.joblib")

# %% [markdown]
# ## Try LogisticRegression

# %%
if True:
    from sklearn.linear_model import LogisticRegression

    # Perform classification with LogisticRegression
    logreg_clf = LogisticRegression()
    t0 = time.time()
    logreg_clf.fit(X_train, y_train)
    t1 = time.time()
    prediction_logreg = logreg_clf.predict(X_test)
    t2 = time.time()
    time_logreg_train = t1-t0
    time_logreg_predict = t2-t1

    print("Results for LogisticRegression()")
    print("Training time: %fs; Prediction time: %fs" % (time_logreg_train, time_logreg_predict))
    print(classification_report(y_test, prediction_logreg))
    most_informative_feature_for_class(vect, logreg_clf, 501)
    print_top10(vect, logreg_clf, logreg_clf.classes_)
