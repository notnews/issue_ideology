# %% [markdown]
# ### Latest
#
# There is just one more iteration of models that I would like to try. We will only do major and topic_1 models (no minor topics model, and only SVM with linear kernel) with the following changes:
#
# 1. Use bills93-114.csv as it has more data. It will need to be cleaned and tokenized though.
#
# *** use old bills dataset between 103 - 112 ***
#
# 2. Support for some topics is very low. For instance, just 2--5 rows for some minor topics. I have revised topic_1 in topic_code.csv to remove most of these topics. So that should improve our classification success a lot.
#
# 3. For test data, can we also output:
# true class, prob_class_1, prob_class_2 ...., .....prob_class_k
#
# Final steps for maj_topics (similar for topic_1):
#
# 1. Read bills93-114.csv
# 2. Clean and tokenize
#
# *** use old bills dataset between 103 - 112 ***
#
# 3. Split long bills into 2.5k chunks. 5k may be still too long. (And I mean 2500 characters, not 2500 words, which is super long. 2500 characters ~ 500 words. I apologize for any confusion.)
# 4. Read in Roberts rules and takes out those tokens
# 5. Remove tokens that appear in 10 or fewer bills. Also remove tokens that appear in more than 5,000 bills.
# 6. Fit SVM with linear kernel
# 7. Merge with topic_code
# 8. For test data, produce: true_class, prob_class_1,..... prob_class_k
# 9. Output top 20 most informative for each class
# 10. Predict all congress (after chunking into 2.5k characters) and all news
#
# Other Notes:
#
# 1. It doesn't appear we are tuning c or gamma in SVM. We can also decide on kernels using cross-validation. See this:
# http://scikit-learn.org/stable/auto_examples/svm/plot_rbf_parameters.html
#
# It is ok for now. But something to look into in the future. We can also look into other models.

# %%
import pandas as pd
import numpy as np
import time

# %% [markdown]
# ## Read Bills dataset (cleaned version)

# %%
df = pd.read_csv('../data/bills-out-clean.csv.gz', nrows=10)
df.columns
# Out:
# Index([u'uid', u'Major', u'Minor', u'clean_text'], dtype='object')

# %%
df = pd.read_csv('../data/bills-out-clean.csv.gz', usecols=['Major', 'Minor', 'clean_text'])
df
# Out:
#        Major  Minor                                         clean_text
# 0         20   2012  congression bill 103th congress us govern prin...
# 1          3    300  congression bill 103th congress us govern prin...
# 2         15   1520  congression bill 103th congress us govern prin...
# 3         20   2000  congression bill 103th congress us govern prin...
# 4         15   1522  congression bill 103th congress us govern prin...
# 5          1    107  congression bill 103th congress us govern prin...
# 6         14   1401  congression bill 103th congress us govern prin...
# 7          1    107  congression bill 103th congress us govern prin...
# 8         14   1406  congression bill 103th congress us govern prin...
# 9          3    331  congression bill 103th congress us govern prin...
# 10        20   2012  congression bill 103th congress us govern prin...
# 11         3    301  congression bill 103th congress us govern prin...
# 12        18   1806  congression bill 103th congress us govern prin...
# 13         2    207  congression bill 103th congress us govern prin...
# 14        15   1504  congression bill 103th congress us govern prin...
# 15         6    601  congression bill 103th congress us govern prin...
# 16         3    302  congression bill 103th congress us govern prin...
# 17        16   1609  congression bill 103th congress us govern prin...
# 18        13   1303  congression bill 103th congress us govern prin...
# 19        21   2101  congression bill 103th congress us govern prin...
# 20        21   2103  congression bill 103th congress us govern prin...
# 21         2    201  congression bill 103th congress us govern prin...
# 22        14   1406  congression bill 103th congress us govern prin...
# 23         5    501  congression bill 103th congress us govern prin...
# 24        16   1609  congression bill 103th congress us govern prin...
# 25        20   2004  congression bill 103th congress us govern prin...
# 26        20   2012  congression bill 103th congress us govern prin...
# 27         3    325  congression bill 103th congress us govern prin...
# 28         1    107  congression bill 103th congress us govern prin...
# 29        15   1504  congression bill 103th congress us govern prin...
# ...      ...    ...                                                ...
# 25325      1    104  congression bill 112th congress us govern prin...
# 25326      5    502  congression bill 112th congress us govern prin...
# 25327     20   2006  congression bill 112th congress us govern prin...
# 25328      3    321  congression bill 112th congress us govern prin...
# 25329      3    321  congression bill 112th congress us govern prin...
# 25330     10   1003  congression bill 112th congress us govern prin...
# 25331     20   2012  congression bill 112th congress us govern prin...
# 25332     21   2103  congression bill 112th congress us govern prin...
# 25333     12   1210  congression bill 112th congress us govern prin...
# 25334      3    321  congression bill 112th congress us govern prin...
# 25335     17   1701  congression bill 112th congress us govern prin...
# 25336     12   1211  congression bill 112th congress us govern prin...
# 25337     20   2001  congression bill 112th congress us govern prin...
# 25338     15   1525  congression bill 112th congress us govern prin...
# 25339      7    711  congression bill 112th congress us govern prin...
# 25340     12   1210  congression bill 112th congress us govern prin...
# 25341     15   1521  congression bill 112th congress us govern prin...
# 25342      5    530  congression bill 112th congress us govern prin...
# 25343      6    602  congression bill 112th congress us govern prin...
# 25344      1    104  congression bill 112th congress us govern prin...
# 25345     13   1303  congression bill 112th congress us govern prin...
# 25346     15   1521  congression bill 112th congress us govern prin...
# 25347     15   1523  congression bill 112th congress us govern prin...
# 25348      7    710  congression bill 112th congress us govern prin...
# 25349     20   2006  congression bill 112th congress us govern prin...
# 25350      1    107  congression bill 112th congress us govern prin...
# 25351     15   1502  congression bill 112th congress us govern prin...
# 25352     13   1303  congression bill 112th congress us govern prin...
# 25353     21   2101  congression bill 112th congress us govern prin...
# 25354      7    704  congression bill 112th congress us govern prin...
#
# [25355 rows x 3 columns]

# %% [markdown]
# ## Split long bill to smaller chunk (2500 chars)

# %%
import re
import textwrap

def insert_chars_split_marker(text, cc=2500):
    # FIXME: text still has number
    text = re.sub('\d+', '', text)
    out = '|'.join(textwrap.wrap(text, cc))
    return out

def insert_words_split_marker(text, wc=500):
    text = re.sub('\d+', '', text)
    words = text.split()
    out = ''
    for i, w in enumerate(words):
        if i != 0 and i % wc == 0:
            out += '|' + w
        else:
            out += ' ' + w
    return out

# %%
if True:
    df['clean_text'] = df['clean_text'].apply(lambda c: insert_chars_split_marker(c, 2500))

# %%
if True:
    s = df['clean_text'].str.split('|', expand=True).stack()
    i = s.index.get_level_values(0)
    new_df = df.loc[i].copy()
    new_df['chunk'] = s.index.get_level_values(1)
    new_df['clean_text'] = s.values
    df = new_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-2a50c72485eb> in <module>()
#       3     i = s.index.get_level_values(0)
#       4     new_df = df.loc[i].copy()
# ----> 5     new_df['chunk'] = s.index.get_level_values(1)
#       6     new_df['clean_text'] = s.values
#       7     df = new_df
#
# /opt/venv/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    2355         else:
#    2356             # set column
# -> 2357             self._set_item(key, value)
#    2358
#    2359     def _setitem_slice(self, key, value):
#
# /opt/venv/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    2421
#    2422         self._ensure_valid_index(value)
# -> 2423         value = self._sanitize_column(key, value)
#    2424         NDFrame._set_item(self, key, value)
#    2425
#
# /opt/venv/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _sanitize_column(self, key, value)
#    2576
#    2577             # turn me into an ndarray
# -> 2578             value = _sanitize_index(value, self.index, copy=False)
#    2579             if not isinstance(value, (np.ndarray, Index)):
#    2580                 if isinstance(value, list) and len(value) > 0:
#
# /opt/venv/local/lib/python2.7/site-packages/pandas/core/series.pyc in _sanitize_index(data, index, copy)
#    2768
#    2769     if len(data) != len(index):
# -> 2770         raise ValueError('Length of values does not match length of ' 'index')
#    2771
#    2772     if isinstance(data, PeriodIndex):
#
# ValueError: Length of values does not match length of index

# %% [markdown]
# ## Vectorize

# %%
import nltk
from nltk import word_tokenize          
from nltk.stem.porter import PorterStemmer
import re
import string

stemmer = PorterStemmer()
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

#def tokenize(text):
#    tokens = nltk.word_tokenize(text)
#    stems = stem_tokens(tokens, stemmer)
#    return stems

def tokenize(text):
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    return stems

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.cross_validation import train_test_split

# %%
with open('../roberts_rules/all_text.txt', 'rt') as f:
    text = f.read()
text = text.decode('ascii', 'ignore')
text = re.sub(r'\d+', '', text)

vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3)) 
vect.fit([text])
roberts_rules = set(vect.get_feature_names())

# %%
#vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3), min_df=0.01)
#vect = CountVectorizer(ngram_range=(2, 3), min_df=0.01) 
#vect = CountVectorizer(ngram_range=(2, 3)) 
#vect = CountVectorizer(ngram_range=(2, 3), min_df=20) 
vect = CountVectorizer(ngram_range=(2, 3), min_df=10, max_df=5000) 
vect.fit(df.clean_text)
# Out:
# CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=5000, max_features=None, min_df=10,
#         ngram_range=(2, 3), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
len(vect.get_feature_names())
# Out:
# 690480

# %%
vocab = []
i = 0
for a in vect.vocabulary_:
    if a not in roberts_rules:
        vocab.append(a)
    else:
        #print a
        i += 1
print("Removed {0:d}".format(i))
print("Total {0:d}".format(len(vocab)))
# Out:
# Removed 4013
# Total 686467

# %%
ng_df = pd.DataFrame(vocab)
ng_df.columns = ['ngram']
ng_df
# Out:
#                              ngram
# 0               author examin book
# 1                     mill process
# 2                  printer connect
# 3                        bb approv
# 4                    agenc sponsor
# 5                   payment method
# 6          compon personnel polici
# 7                     impos health
# 8                 health center ii
# 9                shall submit year
# 10                  fund usc shall
# 11                  formula applic
# 12                 product chapter
# 13              altern staff feder
# 14                  period commiss
# 15        repay secretari treasuri
# 16                     improv awar
# 17               gener rulesubject
# 18            insert applic dollar
# 19                  parent complet
# 20                    hospit retir
# 21               conscienc rescind
# 22            purchas farm product
# 23           action commiss review
# 24                 reprocess spent
# 25            acquisit good servic
# 26                       cite live
# 27               may requir verifi
# 28                    valu qualiti
# 29        amount specifi paragraph
# ...                            ...
# 686437               barrier imped
# 686438        project instal locat
# 686439        equal product applic
# 686440                   ii result
# 686441           sell elig purchas
# 686442      group particip develop
# 686443      report activ secretari
# 686444       amount applic payment
# 686445                exce greater
# 686446                dilig reason
# 686447     basi determin secretari
# 686448    conduct pursuant subsect
# 686449        includ budget justif
# 686450               respect petit
# 686451            appli amend made
# 686452     determin section energi
# 686453               measur assess
# 686454     commiss appoint subsect
# 686455                  intern sex
# 686456            bequest properti
# 686457  percentag generalnot later
# 686458     organ accredit american
# 686459      feder advisori council
# 686460                 examin mean
# 686461                  cstudi sec
# 686462            corpor noncredit
# 686463             incarcer famili
# 686464         subparagraph biiiii
# 686465      provid school opportun
# 686466              stimul develop
#
# [686467 rows x 1 columns]

# %%
ng_df.to_csv('../data/bills-23gram-new.csv', index=False)

# %%
def most_informative_feature_for_class(vectorizer, classifier, classlabel, n=10):
    labelid = list(classifier.classes_).index(classlabel)
    feature_names = vectorizer.get_feature_names()
    topn = sorted(zip(classifier.coef_[labelid], feature_names))[-n:]

    for coef, feat in topn:
        print classlabel, feat, coef

def most_informative_feature_for_class_svm(vectorizer, classifier,  n=10):
    labelid = 3 # this is the coef we're interested in. 
    feature_names = vectorizer.get_feature_names()
    svm_coef = classifier.coef_.toarray() 
    topn = sorted(zip(svm_coef[labelid], feature_names))[-n:]

    for coef, feat in topn:
        print feat, coef

def print_top10(vectorizer, clf, class_labels):
    """Prints features with the highest coefficient values, per class"""
    feature_names = vectorizer.get_feature_names()
    for i, class_label in enumerate(class_labels):
        top10 = np.argsort(clf.coef_[i])[-10:]
        print("%s: %s" % (class_label,
              " | ".join(feature_names[j] for j in top10)))

def get_top_features(vectorizer, clf, class_labels, n=20):
    """Prints features with the highest coefficient values, per class"""
    feature_names = vectorizer.get_feature_names()
    top_features = {}
    for i, class_label in enumerate(class_labels):
        topN = np.argsort(clf.coef_[i])[-n:]
        top_features[class_label] = [feature_names[j] for j in topN][::-1]
    return top_features

# %% [markdown]
# ## Model (Major)

# %%
X = df.clean_text
y = df.Major

X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
#vect = CountVectorizer(ngram_range=(2, 3), min_df=20, vocabulary=vocab)
vect = CountVectorizer(ngram_range=(2, 3), min_df=10, max_df=5000, vocabulary=vocab)

# %%
X_train = vect.transform(X_train)
transformer = TfidfTransformer()
X_train = transformer.fit_transform(X_train)

# %%
X_test = vect.transform(X_test)
transformer = TfidfTransformer()
X_test = transformer.fit_transform(X_test)

# %%
# Perform classification with SVM, kernel=linear
classifier_liblinear = svm.LinearSVC()
t0 = time.time()
classifier_liblinear.fit(X_train, y_train)
t1 = time.time()
prediction_liblinear = classifier_liblinear.predict(X_test)
t2 = time.time()
time_liblinear_train = t1-t0
time_liblinear_predict = t2-t1

print("Results for LinearSVC()")
print("Training time: %fs; Prediction time: %fs" % (time_liblinear_train, time_liblinear_predict))
print(classification_report(y_test, prediction_liblinear))
# Out:
# Results for LinearSVC()
# Training time: 123.404556s; Prediction time: 0.618879s
#              precision    recall  f1-score   support
#
#           1       0.60      0.55      0.57      1071
#           2       0.75      0.65      0.70       368
#           3       0.86      0.92      0.89      3062
#           4       0.82      0.82      0.82       607
#           5       0.74      0.76      0.75      1159
#           6       0.83      0.85      0.84      1256
#           7       0.80      0.78      0.79      1050
#           8       0.82      0.85      0.84      1205
#          10       0.87      0.88      0.88      1029
#          12       0.78      0.79      0.79      1448
#          13       0.73      0.68      0.70       819
#          14       0.80      0.76      0.78       516
#          15       0.80      0.80      0.80      1589
#          16       0.83      0.82      0.82      1840
#          17       0.76      0.65      0.70       434
#          18       0.83      0.80      0.81       898
#          19       0.80      0.79      0.79       626
#          20       0.75      0.73      0.74      1737
#          21       0.85      0.89      0.87      1734
#          99       0.64      0.53      0.58       110
#
# avg / total       0.80      0.80      0.80     22558

# %%
most_informative_feature_for_class(vect, classifier_liblinear, 99)
#most_informative_feature_for_class_svm(vect, classifier_linear)
# Out:
# 99 date file petit 0.950818487668
# 99 amend section amend 0.964538504304
# 99 author request 0.992795516663
# 99 mean bill provid 1.12612501026
# 99 reaffirm agreement 1.26709192351
# 99 act relief 1.45874390103
# 99 judiciari bill relief 1.9664402076
# 99 st session relief 2.32482001213
# 99 session relief 2.66888917435
# 99 bill relief 2.71392383165

# %%
print_top10(vect, classifier_liblinear, classifier_liblinear.classes_)
# Out:
# 1: amend relat section | gift tax | deficit reduct | public debt | regular credit | tax administr | qualifi manufactur | direct spend | sale tax | medicar choic
# 2: partialbirth abort | vote system | girl women | perform abort | fair hous | person health inform | sexual orient | racial profil | vote right | genet inform
# 3: medic care | amend titl xviii | item servic | secretari health human | state health | medic malpractic | nation health | health servic act | health plan | prescript drug
# 4: agricultur product | depart agricultur | genet engin | food safeti | agricultur research | agricultur commod | crop year | anim drug | farmer rancher | food product
# 5: immigr enforc | amend immigr | commun board | pension plan | wto particip | unemploy compens | illeg alien | youth apprenticeship | infrastructur project | child care
# 6: local partnership | public school | educ save | elementari secondari | secretari educ | depart educ | higher educ | head start | educ assist | student loan
# 7: nuclear wast | hazard wast | water qualiti | insur particip | solid wast | ballast water | respons action | coral reef | fisheri manag | asbesto claim
# 8: energi conserv | energi polici | pipelin safeti | fuel cell | natur ga | secretari energi | feder power | clean energi | crude oil | oil ga
# 10: aviat secur | transport plan | air transport | rail carrier | surfac transport | air carrier | transport system | transport infrastructur | public transport | coast guard
# 12: child abus | death penalti | feder prison | juvenil delinqu | child support | bureau prison | administr fema | money launder | committe judiciari | shall imprison
# 13: center organ | nation servic | smart annuiti | individu disabl | account holder | welfar recipi | welfar reform | obra amend | social servic | older individu
# 14: invest save | hous credit | hous agenc | afford hous | grant amount | commun develop | consensu committe | delta region | hous act | empower zone
# 15: antitrust law | depart commerc | profession box | store valu | flood insur | interst insur | depositori institut | offshor aquacultur | nation insur | small busi
# 16: reserv compon | militari instal | chemic facil | secretari navi | war terror | air forc | secretari defens | homeland secur | arm forc | depart defens
# 17: innov prize | news inform | commerci space | space transport | region ocean | telecommun carrier | realloc commiss | broadband servic | geoloc inform | commun act
# 18: trade deficit | nafta countri | tariff act | amend act amend | countervail duti | exportimport bank | secretari trade | export control | trade agreement | custom servic
# 19: govern sudan | obstetr fistula | australia unit | develop countri | foreign servic | peac corp | depart state | foreign assist | unit nation | human right
# 20: execut agenc | joint committe | dutch john | independ counsel | hass avocado | gener elect | public build | feder elect | postal servic | district columbia
# 21: nativ american | nation park | nation forest | critic miner | dam safeti | miner activ | nativ hawaiian | indian reserv | indian tribe | water resourc
# 99: date file petit | amend section amend | author request | mean bill provid | reaffirm agreement | act relief | judiciari bill relief | st session relief | session relief | bill relief

# %%
topics_df = pd.read_csv('../data/topic_code.csv')
topics_map = {}
for r in topics_df.iterrows():
    topics_map[r[1].code] = r[1].topic

# %%
top_features = get_top_features(vect, classifier_liblinear, classifier_liblinear.classes_)
top_features_df = pd.DataFrame(top_features)
columns = []
for c in top_features_df.columns:
    cname = topics_df[topics_df.code == c].topic.values[0]
    columns.append(cname)
top_features_df.columns = columns
top_features_df.to_csv('../data/major_bills_top20_new.csv', index=False)
top_features_df
# Out:
#          Macroeconomics Civil Rights, Minority Issues, and Civil Liberties  \
# 0         medicar choic                                       genet inform
# 1              sale tax                                         vote right
# 2          direct spend                                      racial profil
# 3    qualifi manufactur                                      sexual orient
# 4         tax administr                               person health inform
# 5        regular credit                                          fair hous
# 6           public debt                                      perform abort
# 7        deficit reduct                                         girl women
# 8              gift tax                                        vote system
# 9   amend relat section                                 partialbirth abort
# 10        taxabl person                                          work forc
# 11           capit gain                                     perman partner
# 12      properti servic                                      person inform
# 13            feder tax                                    civil right act
# 14           debt incur                                     religi freedom
# 15   congression budget                               grammleachbliley act
# 16          budget year                                          drug test
# 17          old section                             discriminatori practic
# 18      portland oregon                                    person identifi
# 19          capabl oper                                      health inform
#
#                     Health          Agriculture  \
# 0           prescript drug         food product
# 1              health plan       farmer rancher
# 2        health servic act            anim drug
# 3            nation health            crop year
# 4         medic malpractic    agricultur commod
# 5             state health  agricultur research
# 6   secretari health human          food safeti
# 7              item servic          genet engin
# 8         amend titl xviii    depart agricultur
# 9               medic care   agricultur product
# 10          health coverag       specialti crop
# 11            health insur        dairi compact
# 12        protect individu  committe agricultur
# 13          region allianc       food establish
# 14         tobacco product      poultri product
# 15             secur futur          farm credit
# 16    public health servic     amend agricultur
# 17      dietari supplement   valuead agricultur
# 18              care fraud        dairi product
# 19           underag drink          nation fund
#
#    Labor, Employment, and Immigration             Education  \
# 0                          child care          student loan
# 1               infrastructur project           educ assist
# 2                youth apprenticeship            head start
# 3                         illeg alien           higher educ
# 4                    unemploy compens           depart educ
# 5                        wto particip        secretari educ
# 6                        pension plan  elementari secondari
# 7                        commun board             educ save
# 8                        amend immigr         public school
# 9                       immigr enforc     local partnership
# 10                      career center       number children
# 11                amend immigr nation           nation educ
# 12                      immigr servic      school construct
# 13                   workforc develop    profession develop
# 14                       employ shall             educ loan
# 15                        depend care              educ act
# 16                        numer limit          school board
# 17                        compens act         committe educ
# 18                        labor organ         youth develop
# 19                  profession provid        lifelong learn
#
#               Environment             Energy           Transportation  \
# 0           asbesto claim             oil ga              coast guard
# 1           fisheri manag          crude oil         public transport
# 2              coral reef       clean energi  transport infrastructur
# 3          respons action        feder power         transport system
# 4           ballast water   secretari energi              air carrier
# 5              solid wast           natur ga         surfac transport
# 6          insur particip          fuel cell             rail carrier
# 7           water qualiti     pipelin safeti            air transport
# 8             hazard wast      energi polici           transport plan
# 9            nuclear wast     energi conserv              aviat secur
# 10           conserv plan  energi laboratori         depart transport
# 11            invas speci       renew energi              gener aviat
# 12        chemic substanc    feder power act           highway safeti
# 13              great ape      energi effici      secretari transport
# 14         migratori bird   restor agreement            motor carrier
# 15         offset project    energi properti              feder aviat
# 16  environment technolog      electr energi             rail passeng
# 17    environment protect      electr servic         railroad carrier
# 18         conserv credit      nuclear facil          transport secur
# 19            trade facil      depart energi       northeast corridor
#
#    Law, Crime, and Family Issues     Social Welfare  \
# 0                 shall imprison     older individu
# 1             committe judiciari      social servic
# 2                  money launder         obra amend
# 3                 administr fema      welfar reform
# 4                  bureau prison      welfar recipi
# 5                  child support     account holder
# 6                juvenil delinqu    individu disabl
# 7                   feder prison      smart annuiti
# 8                  death penalti      nation servic
# 9                     child abus       center organ
# 10                 violent crime  person retir save
# 11               firearm ammunit     employ network
# 12            intercountri adopt    nonprofit agenc
# 13                   adopt child     opportun board
# 14                   cover grant      licens vendor
# 15                 youth violenc    polici committe
# 16     methamphetamin laboratori       chemic sourc
# 17                domest violenc          ccdbg act
# 18      refer committe judiciari   individu develop
# 19                 juvenil crime      insur benefit
#
#    Community Development and Housing Issues  \
# 0                              empower zone
# 1                                  hous act
# 2                              delta region
# 3                         consensu committe
# 4                            commun develop
# 5                              grant amount
# 6                               afford hous
# 7                                hous agenc
# 8                               hous credit
# 9                               invest save
# 10                           enterpris zone
# 11                          collabor applic
# 12                       particip jurisdict
# 13                      invest save account
# 14                    foreclosur commission
# 15                       individu homestead
# 16                        public hous agenc
# 17                          nation hous act
# 18                        homeless individu
# 19                            mortgag insur
#
#    Banking, Finance, and Domestic Commerce             Defense  \
# 0                               small busi       depart defens
# 1                             nation insur            arm forc
# 2                       offshor aquacultur      homeland secur
# 3                      depositori institut    secretari defens
# 4                            interst insur            air forc
# 5                              flood insur          war terror
# 6                               store valu      secretari navi
# 7                           profession box        chemic facil
# 8                           depart commerc     militari instal
# 9                            antitrust law       reserv compon
# 10                         financi compani      closur realign
# 11                         copyright owner      ballist missil
# 12                         develop compani       rural veteran
# 13                        comptrol currenc       veteran spous
# 14                             state insur  militari construct
# 15                           secur exchang     nation intellig
# 16                             credit card          marin corp
# 17                            credit union      feder director
# 18                       unclassifi inform     ammonium nitrat
# 19                          product safeti       commerci item
#
#    Space, Science, Technology and Communications      Foreign Trade  \
# 0                                     commun act      custom servic
# 1                                  geoloc inform    trade agreement
# 2                               broadband servic     export control
# 3                                realloc commiss    secretari trade
# 4                             telecommun carrier  exportimport bank
# 5                                   region ocean   countervail duti
# 6                                space transport    amend act amend
# 7                                 commerci space         tariff act
# 8                                    news inform      nafta countri
# 9                                    innov prize      trade deficit
# 10                                 weather modif      rough diamond
# 11                               telephon servic       suspens duti
# 12                                  video servic     decrypt inform
# 13                              public broadcast  disput settlement
# 14                                 electron mail      trade act usc
# 15                       greekth greekth greekth           lo angel
# 16                                 motion pictur          trade act
# 17                                 digit televis    committe financ
# 18                                commun commiss      canada mexico
# 19                                   digit media     postship verif
#
#    International Affairs and Foreign Aid Government Operations  \
# 0                            human right     district columbia
# 1                            unit nation         postal servic
# 2                         foreign assist           feder elect
# 3                           depart state          public build
# 4                              peac corp           gener elect
# 5                         foreign servic          hass avocado
# 6                        develop countri      independ counsel
# 7                         australia unit            dutch john
# 8                        obstetr fistula        joint committe
# 9                           govern sudan          execut agenc
# 10                             delet sec         commemor coin
# 11                   nongovernment organ        polit committe
# 12                            world bank     nation manufactur
# 13                            insur loss            land grant
# 14                        foreign affair       report individu
# 15                 committe intern relat         govern reform
# 16                         foreign relat          paper ballot
# 17                          panama canal      system transform
# 18                      healthcar servic         legisl branch
# 19                            organ issu            memori day
#
#    Public Lands and Water Management Other, Miscellaneous, and Human Interest
# 0                      water resourc                              bill relief
# 1                       indian tribe                           session relief
# 2                      indian reserv                        st session relief
# 3                     nativ hawaiian                    judiciari bill relief
# 4                        miner activ                               act relief
# 5                         dam safeti                       reaffirm agreement
# 6                       critic miner                         mean bill provid
# 7                      nation forest                           author request
# 8                        nation park                      amend section amend
# 9                     nativ american                          date file petit
# 10                 commonwealth guam                          debtor individu
# 11                      resourc bill                       code amend section
# 12                      heritag area                                mr barlow
# 13                  committe resourc                          bankruptci judg
# 14                       river basin                          provid reliquid
# 15                        mine claim                              naval aviat
# 16                     nation histor                 refer committe judiciari
# 17                       scienc park                                tax claim
# 18            refer committe resourc                           drawback claim
# 19                      water suppli                            provid relief

# %%
from sklearn.externals import joblib

joblib.dump(vect, "../models/vec_count_bills_23gram_new.joblib")
joblib.dump(classifier_liblinear, "../models/major_bills_clf_liblinear_new.joblib")
# Out:
# ['../models/major_bills_clf_liblinear_new.joblib',
#  '../models/major_bills_clf_liblinear_new.joblib_01.npy',
#  '../models/major_bills_clf_liblinear_new.joblib_02.npy',
#  '../models/major_bills_clf_liblinear_new.joblib_03.npy']

# %%
y_test_df = pd.DataFrame(y_test)
y_test_df['true_value'] = y_test_df['Minor'].apply(lambda c: topics_map[c])
y_test_df.reset_index(drop=True, inplace=True)

prob = classifier_liblinear.decision_function(X_test)
prob_df = pd.DataFrame(prob)
columns = []
for c in classifier_liblinear.classes_:
    cname = topics_map[c]
    columns.append(cname)
prob_df.columns = columns

result_df = pd.concat([y_test_df[['true_value']], prob_df], axis=1)
result_df.to_csv('../data/test_prediction_major.csv', index=False)
result_df

# %% [markdown]
# ## Try SGDClassifier

# %%
if False:
    from sklearn.linear_model import SGDClassifier

    elastic_clf = SGDClassifier(loss='log', alpha=.00002, n_iter=200, penalty="elasticnet")
    t0 = time.time()
    elastic_clf.fit(X_train, y_train)
    t1 = time.time()
    prediction_elastic = elastic_clf.predict(X_test)
    t2 = time.time()
    time_elastic_train = t1-t0
    time_elastic_predict = t2-t1

    print("Results for Elastic Net")
    print("Training time: %fs; Prediction time: %fs" % (time_elastic_train, time_elastic_predict))
    print(classification_report(y_test, prediction_elastic))

# %%
if False:
    most_informative_feature_for_class(vect, elastic_clf, 99)

# %%
if False:
    print_top10(vect,  elastic_clf,  elastic_clf.classes_)

# %% [markdown]
# ## Model (topic_1 == 1)

# %%
selected_topics = topics_df[topics_df.topic_1 == 1].code.unique()

# %%
selected_topics
# Out:
# array([ 101,  103,  105,  107,  201,  202,  206,  207,  209,  301,  302,
#         323,  324,  331,  332,  333,  335,  403,  404,  501,  502,  503,
#         504,  505,  508,  529,  601,  603,  607,  609,  701,  703,  704,
#         705,  709,  710,  801,  802,  803,  806,  807,  900, 1002, 1003,
#        1005, 1006, 1007, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209,
#        1301, 1302, 1303, 1304, 1401, 1501, 1502, 1504, 1507, 1521, 1522,
#        1523, 1525, 1602, 1603, 1605, 1609, 1610, 1612, 1615, 1701, 1706,
#        1707, 1709, 1802, 1807, 1901, 1915, 1925, 1926, 1927, 2002, 2003,
#        2006, 2010, 2011, 2012, 2013, 2101, 2102])

# %%
X = df[df.Minor.isin(selected_topics)].clean_text
y = df[df.Minor.isin(selected_topics)].Minor

X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
X_train = vect.transform(X_train)
transformer = TfidfTransformer()
X_train = transformer.fit_transform(X_train)

# %%
X_test = vect.transform(X_test)
transformer = TfidfTransformer()
X_test = transformer.fit_transform(X_test)

# %%
# Perform classification with SVM, kernel=linear
classifier_liblinear = svm.LinearSVC()
t0 = time.time()
classifier_liblinear.fit(X_train, y_train)
t1 = time.time()
prediction_liblinear = classifier_liblinear.predict(X_test)
t2 = time.time()
time_liblinear_train = t1-t0
time_liblinear_predict = t2-t1

print("Results for LinearSVC()")
print("Training time: %fs; Prediction time: %fs" % (time_liblinear_train, time_liblinear_predict))
print(classification_report(y_test, prediction_liblinear))
# Out:
# Results for LinearSVC()
# Training time: 237.174071s; Prediction time: 1.236352s
#              precision    recall  f1-score   support
#
#         101       0.40      0.29      0.33         7
#         103       0.00      0.00      0.00         3
#         105       0.68      0.56      0.61       312
#         107       0.66      0.74      0.70       615
#         201       0.80      0.67      0.73        12
#         202       0.88      0.43      0.58        51
#         206       0.88      0.60      0.71        25
#         207       0.90      0.64      0.75        28
#         209       0.00      0.00      0.00         1
#         301       0.67      0.75      0.71       864
#         302       0.62      0.60      0.61       440
#         323       0.62      0.42      0.50        73
#         324       0.50      0.35      0.41        65
#         331       0.68      0.63      0.65       156
#         332       0.67      0.62      0.65       207
#         333       0.64      0.67      0.66        67
#         335       0.69      0.75      0.72       187
#         403       0.86      0.92      0.89       102
#         404       0.75      0.90      0.82        20
#         501       0.92      0.82      0.87        57
#         502       0.72      0.62      0.67       136
#         503       0.74      0.73      0.74       366
#         504       0.86      0.92      0.89        39
#         505       0.62      0.67      0.64        51
#         508       0.77      0.89      0.83        80
#         529       0.93      0.93      0.93        28
#         601       0.78      0.83      0.80       274
#         603       0.74      0.59      0.66        91
#         607       0.75      0.81      0.78       140
#         609       0.78      0.70      0.74        10
#         701       0.67      0.74      0.70        78
#         703       0.71      0.74      0.72        53
#         704       0.86      0.82      0.84       152
#         705       0.64      0.66      0.65       119
#         709       0.79      0.79      0.79       258
#         710       0.57      0.59      0.58       131
#         801       0.73      0.77      0.75        57
#         802       0.77      0.76      0.77       119
#         803       0.67      0.70      0.68       312
#         806       0.53      0.46      0.49       211
#         807       0.45      0.44      0.45       215
#        1002       0.87      0.85      0.86       348
#        1003       0.94      0.97      0.95       194
#        1005       0.84      0.90      0.87        87
#        1006       0.67      0.58      0.62        71
#        1007       0.85      0.88      0.87       155
#        1202       0.69      0.51      0.59        39
#        1203       0.80      0.78      0.79        73
#        1204       0.79      0.78      0.79       114
#        1205       0.93      0.78      0.85        32
#        1206       0.71      0.84      0.77       116
#        1207       0.62      0.58      0.60        55
#        1208       0.70      0.64      0.67       222
#        1209       0.80      0.77      0.78       158
#        1301       0.51      0.59      0.55        44
#        1302       0.64      0.67      0.65       186
#        1303       0.80      0.78      0.79       236
#        1304       0.74      0.61      0.67        94
#        1401       0.79      0.78      0.79       127
#        1501       0.81      0.82      0.81       320
#        1502       0.70      0.72      0.71       105
#        1504       0.75      0.70      0.72        92
#        1507       0.91      0.96      0.93        80
#        1521       0.68      0.69      0.69       239
#        1522       0.86      0.80      0.83       147
#        1523       0.81      0.76      0.78       166
#        1525       0.65      0.62      0.63       112
#        1602       0.50      0.12      0.20         8
#        1603       0.63      0.72      0.68       105
#        1605       0.71      0.65      0.68        46
#        1609       0.63      0.80      0.71       147
#        1610       0.85      0.81      0.83        36
#        1612       0.77      0.77      0.77        31
#        1615       0.70      0.66      0.68       182
#        1701       0.85      0.90      0.88        39
#        1706       0.69      0.65      0.67        83
#        1707       0.78      0.75      0.76        79
#        1709       0.84      0.60      0.70        45
#        1802       0.87      0.83      0.85       132
#        1807       0.95      0.97      0.96       456
#        1901       0.83      0.85      0.84        79
#        1915       1.00      1.00      1.00         3
#        1925       0.87      0.87      0.87        45
#        1926       0.80      0.93      0.86        30
#        1927       0.66      0.61      0.64        44
#        2002       0.63      0.60      0.62       192
#        2003       0.96      0.89      0.92        81
#        2006       0.95      0.94      0.94        80
#        2010       0.00      0.00      0.00         1
#        2011       0.61      0.63      0.62        86
#        2012       0.89      0.91      0.90       258
#        2013       0.79      0.85      0.81        13
#        2101       0.87      0.89      0.88       393
#        2102       0.90      0.91      0.90       429
#
# avg / total       0.75      0.75      0.74     12947
# /opt/venv/local/lib/python2.7/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
most_informative_feature_for_class(vect, classifier_liblinear, 501)
# Out:
# 501 drugfre workplac program 0.954687110151
# 501 expos person 0.960065124841
# 501 safeti health act 0.976369504038
# 501 cover ill 0.986308017987
# 501 asbesto claim 1.01969459724
# 501 modif thereof 1.10235644819
# 501 energi employe 1.18290098909
# 501 possibl modif 1.18658501104
# 501 safeti health 1.36630269879
# 501 drugfre workplac 1.40521522807

# %%
print_top10(vect, classifier_liblinear, classifier_liblinear.classes_)
# Out:
# 101: price goug | cost live | function offic | feder statist servic | statist servic | statist data center | statist data | price stabil | feder statist | state shall effect
# 103: regul guidanc | purpos tax impos | independ contractor | temporari increas | total wage | state workforc | unemploy rate | increas unemploy | unit state workforc | busi incub
# 105: commiss bill | budget author | committe budget | deficit reduct | sequestr order | act amend insert | spend reduct | direct spend | public debt | medicar choic
# 107: busi activ | portland oregon | capit gain | tax administr | foreign corpor | gift tax | busi entiti | revenu servic | intern revenu servic | sale tax
# 201: elimin racial profil | elimin racial | harass intimid | morril act | qualifi minor | servic personnel | cultur compet | institut slaveri | custom servic personnel | racial profil
# 1915: sec section | sentenc strike appropri | canal commiss | panama canal commiss | section panama | section panama canal | canal act usc | canal act | panama canal act | panama canal
# 1925: categori persecut | north korean | hagu convent | violenc women girl | member commiss | act countri | amnesti intern | govern sudan | religi persecut | human right
# 1926: special olymp | crimin court | intern crimin | intern crimin court | unit state olymp | state olymp | strike constitut | world health | foreclosur prevent | unit nation
# 1927: militari commiss chapter | foreign state | review commiss | protect america | intern terror | terrorist organ | insur loss | plastic explos | al qaeda | militari commiss
# 2002: public servic | public pension | major rule | action purpos | risk assess | system transform | nation manufactur | public printer | inspector gener | regulatori action
# 2003: bypass mail | cover postal | post offic | postmast gener | rate postag | offici mail | postal regulatori commiss | postal regulatori | postag stamp | postal servic
# 2006: congression gold medal | coin act | unit state mint | state mint | bald eagl | travel promot | educ outreach | coin issu | gold medal | commemor coin
# 2010: act amend titl | senat novemb attest | novemb attest secretari | provid crimin | provid crimin penalti | th cir | penalti traffick | code provid crimin | traffick counterfeit | counterfeit mark
# 2011: war power | avail internet | librarian congress | independ counsel | use forc | member employe | librari congress | legisl branch | member hous repres | disapprov bill
# 2012: elig candid | lobbi activ | polit organ | polit committe | voter registr | lobbi disclosur | elect campaign | report individu | gener elect | feder elect
# 2013: statist purpos | resid abroad | independ redistrict | censu bureau | apportion repres congress | american resid | redistrict plan | censu popul | director censu | decenni censu
# 2101: histor preserv | commemor work | nation heritag | nation memori | smithsonian institut | scienc park | nation monument | nation histor | heritag area | nation park
# 2102: land claim | bureau indian | indian game | game oper | indian land | indian affair | indian reserv | nativ american | nativ hawaiian | indian tribe

# %%
top_features = get_top_features(vect, classifier_liblinear, classifier_liblinear.classes_)
top_features_df = pd.DataFrame(top_features)
columns = []
for c in top_features_df.columns:
    cname = topics_df[topics_df.code == c].topic.values[0]
    columns.append(cname)
top_features_df.columns = columns
top_features_df.to_csv('../data/topic_1_bills_top20_new.csv', index=False)
top_features_df
# Out:
#    Inflation, Prices, and Interest Rates       Unemployment Rate  \
# 0                     state shall effect              busi incub
# 1                          feder statist     unit state workforc
# 2                           price stabil        increas unemploy
# 3                           statist data           unemploy rate
# 4                    statist data center          state workforc
# 5                         statist servic              total wage
# 6                   feder statist servic       temporari increas
# 7                         function offic     independ contractor
# 8                              cost live        purpos tax impos
# 9                             price goug           regul guidanc
# 10                     unit state dollar   percent nation averag
# 11                          state dollar   shall individu repres
# 12                      costofliv adjust              purpos tax
# 13                          nation emerg            unemploy tax
# 14            methodolog develop section   member shall individu
# 15                          statist area  provid paragraph regul
# 16                       valu unit state    capita incom percent
# 17                 bureau econom analysi         employe classif
# 18                           data center      statement independ
# 19                          index govern             wage insert
#
#    National Budget and Debt Taxation, Tax policy, and Tax Reform  \
# 0             medicar choic                             sale tax
# 1               public debt                 intern revenu servic
# 2              direct spend                        revenu servic
# 3              spend reduct                          busi entiti
# 4          act amend insert                             gift tax
# 5            sequestr order                       foreign corpor
# 6            deficit reduct                        tax administr
# 7           committe budget                           capit gain
# 8             budget author                      portland oregon
# 9              commiss bill                           busi activ
# 10       congression budget                   section amend read
# 11            poundag quota                            feder tax
# 12          elig manag care                  amend relat section
# 13           sovereign debt                          capabl oper
# 14              choic organ                            incom tax
# 15      medicar choic organ                  amend intern revenu
# 16               elig manag                          inpati drug
# 17        manag care provid                         amend intern
# 18             addit peanut                             roth ira
# 19               debt limit                         cover inpati
#
#    Ethnic Minority and Racial Group Discrimination  \
# 0                                    racial profil
# 1                          custom servic personnel
# 2                                 institut slaveri
# 3                                    cultur compet
# 4                                 servic personnel
# 5                                    qualifi minor
# 6                                       morril act
# 7                                   harass intimid
# 8                                    elimin racial
# 9                             elimin racial profil
# 10                                  program action
# 11                                   second morril
# 12                               second morril act
# 13                                racial discrimin
# 14                                     person race
# 15                                   qualifi women
# 16                                  intimid person
# 17                                   nation origin
# 18                               fundament freedom
# 19                                  would particip
#
#    Gender and Sexual Orientation Discrimination  \
# 0                                 sexual orient
# 1                                perman partner
# 2                                 sexual harass
# 3                                 gender equiti
# 4                            perman partnership
# 5                                    girl women
# 6                            econom selfsuffici
# 7                               women scientist
# 8                                administr judg
# 9                              conflict prevent
# 10                                  basi sexual
# 11                           basi sexual orient
# 12                              civil right act
# 13                             afterschool care
# 14                                 legal purpos
# 15                          shall alloc program
# 16                                    work forc
# 17                                 advanc women
# 18                                 fire station
# 19                         selfsuffici standard
#
#    Voting Rights, Participation, and Related Issues  \
# 0                                        vote right
# 1                                       vote system
# 2                                     board advisor
# 3                                    standard board
# 4                                    absente ballot
# 5                                       local elect
# 6                              uniform servic voter
# 7                                      servic voter
# 8                                      parti candid
# 9                                  individu convict
# 10                               protect vote right
# 11                                state local elect
# 12                                   convict feloni
# 13                             standard board board
# 14                                     qualifi vote
# 15                                    equal protect
# 16                                     elect offici
# 17                                   uniform servic
# 18                                     vote process
# 19                                 develop committe
#
#    Freedom of Speech & Religion Anti-Government Activities  \
# 0            partialbirth abort                covert test
# 1                  unborn child                   time war
# 2                 perform abort              ensur citizen
# 3                   free speech             secur screener
# 4                religi freedom              anoth countri
# 5              reproduct health          unless unit state
# 6                   relat abort                unless unit
# 7               sexual explicit                detain unit
# 8                     flag unit          detain unit state
# 9                  abort servic           unit state first
# 10                  first amend                 test secur
# 11              flag unit state               advanc notic
# 12                   right life    treati intern agreement
# 13                 abort provid              treati intern
# 14                religi belief          unit state detain
# 15                 outsid cover               state detain
# 16         reserv state respect                state first
# 17             exercis religion         unit state citizen
# 18                 free exercis              state citizen
# 19                 power reserv              secur airport
#
#    Comprehensive health care reform           ...            \
# 0                    region allianc           ...
# 1                     nation health           ...
# 2                     advanc direct           ...
# 3                      health secur           ...
# 4                      state health           ...
# 5                     commun health           ...
# 6                      health board           ...
# 7                       health plan           ...
# 8                antimicrobi resist           ...
# 9                     health inform           ...
# 10              nation health board           ...
# 11                   languag servic           ...
# 12                    refer product           ...
# 13                     rural health           ...
# 14                   corpor allianc           ...
# 15                    certif review           ...
# 16                     certifi plan           ...
# 17                    class program           ...
# 18                   health profess           ...
# 19                       medic save           ...
#
#         Terrorism, Hijacking Government Efficiency and Bureaucratic Oversight  \
# 0           militari commiss                                regulatori action
# 1                   al qaeda                                  inspector gener
# 2             plastic explos                                   public printer
# 3                 insur loss                                nation manufactur
# 4            terrorist organ                                 system transform
# 5              intern terror                                      risk assess
# 6            protect america                                    action purpos
# 7             review commiss                                       major rule
# 8              foreign state                                   public pension
# 9   militari commiss chapter                                    public servic
# 10           classifi inform                                    legisl propos
# 11            materi support                                    agenc program
# 12           commiss chapter                                     major system
# 13              terror activ                                      nontax debt
# 14            insert conspir                                       head cover
# 15       terrorist watchlist                                       term graze
# 16           conspir attempt                                  secretari state
# 17            guantanamo bay                               contract personnel
# 18                act terror                              publicpriv competit
# 19               america act                             inspect audit review
#
#    Postal Service Issues (Including Mail Fraud)  \
# 0                                 postal servic
# 1                                  postag stamp
# 2                             postal regulatori
# 3                     postal regulatori commiss
# 4                                   offici mail
# 5                                   rate postag
# 6                                postmast gener
# 7                                    post offic
# 8                                  cover postal
# 9                                   bypass mail
# 10                                   class mail
# 11                                     rate fee
# 12                               thereof offici
# 13                               compens reform
# 14                           regulatori commiss
# 15                             benefit structur
# 16                         special postag stamp
# 17                               special postag
# 18                                 state postal
# 19                            unit state postal
#
#    Currency, Commemorative Coins, Medals, U.S. Mint  \
# 0                                     commemor coin
# 1                                        gold medal
# 2                                         coin issu
# 3                                     educ outreach
# 4                                     travel promot
# 5                                         bald eagl
# 6                                        state mint
# 7                                   unit state mint
# 8                                          coin act
# 9                            congression gold medal
# 10                                 congression gold
# 11                                      circul coin
# 12                                        cent coin
# 13                                   quarter dollar
# 14                                feder reserv note
# 15                                      reserv note
# 16                        requir secretari treasuri
# 17                                     legal tender
# 18                                     coin program
# 19                                    state currenc
#
#    Presidential Impeachment & Scandal  \
# 0                    counterfeit mark
# 1                traffick counterfeit
# 2                  code provid crimin
# 3                    penalti traffick
# 4                              th cir
# 5               provid crimin penalti
# 6                       provid crimin
# 7             novemb attest secretari
# 8                 senat novemb attest
# 9                      act amend titl
# 10                  state code provid
# 11                     st session act
# 12                  session act amend
# 13                     crimin penalti
# 14                  pass senat novemb
# 15                       senat novemb
# 16                      novemb attest
# 17                        code provid
# 18                           mark use
# 19                   counterfeit good
#
#    Federal Government Branch Relations and Administrative Issues, Congressional Operations  \
# 0                                      disapprov bill
# 1                                  member hous repres
# 2                                       legisl branch
# 3                                    librari congress
# 4                                      member employe
# 5                                            use forc
# 6                                    independ counsel
# 7                                  librarian congress
# 8                                      avail internet
# 9                                           war power
# 10                                          item veto
# 11                                      gener counsel
# 12                                     complain parti
# 13                                          limit tax
# 14                                  limit tax benefit
# 15                                pay member congress
# 16                                legisl branch feder
# 17                                      committe bill
# 18                                congression employe
# 19                                      special advoc
#
#    Regulation of Political Campaigns, Political Advertising, PAC regulation, Government Ethics  \
# 0                                         feder elect
# 1                                         gener elect
# 2                                     report individu
# 3                                      elect campaign
# 4                                     lobbi disclosur
# 5                                       voter registr
# 6                                      polit committe
# 7                                         polit organ
# 8                                         lobbi activ
# 9                                         elig candid
# 10                                       paper ballot
# 11                                independ expenditur
# 12                                   contribut person
# 13                                   presidenti elect
# 14                                        polit parti
# 15                                lobbi disclosur act
# 16                                    elect administr
# 17                                       campaign act
# 18                               feder elect campaign
# 19                                 elect campaign act
#
#                          Census  \
# 0                 decenni censu
# 1                director censu
# 2                   censu popul
# 3               redistrict plan
# 4                american resid
# 5     apportion repres congress
# 6                  censu bureau
# 7           independ redistrict
# 8                  resid abroad
# 9                statist purpos
# 10                   censu data
# 11          counti metropolitan
# 12           redistrict commiss
# 13  independ redistrict commiss
# 14             apportion repres
# 15               depart commerc
# 16                 bureau censu
# 17                feder statist
# 18           state censu bureau
# 19                statist agenc
#
#    National Parks, Memorials, Historic Sites, and Recreation  \
# 0                                         nation park
# 1                                        heritag area
# 2                                       nation histor
# 3                                     nation monument
# 4                                         scienc park
# 5                                smithsonian institut
# 6                                       nation memori
# 7                                      nation heritag
# 8                                       commemor work
# 9                                      histor preserv
# 10                                        park servic
# 11                                 nation park servic
# 12                                      nation museum
# 13                                 secretari interior
# 14                                   concess contract
# 15                                     secretari armi
# 16                                paleontolog resourc
# 17                                   conserv reinvest
# 18                                         manag plan
# 19                               conserv reinvest act
#
#    Native American Affairs
# 0             indian tribe
# 1           nativ hawaiian
# 2           nativ american
# 3            indian reserv
# 4            indian affair
# 5              indian land
# 6                game oper
# 7              indian game
# 8            bureau indian
# 9               land claim
# 10            urban indian
# 11            indian child
# 12            alaska nativ
# 13             water right
# 14        settlement trust
# 15             tribal educ
# 16           indian health
# 17             tribe shall
# 18              held trust
# 19    settlement agreement
#
# [20 rows x 94 columns]

# %%
from sklearn.externals import joblib

#joblib.dump(vect, "../models/vec_count_bills_23gram.joblib")
joblib.dump(classifier_liblinear, "../models/topic_1_bills_clf_liblinear_new.joblib")
# Out:
# ['../models/topic_1_bills_clf_liblinear_new.joblib',
#  '../models/topic_1_bills_clf_liblinear_new.joblib_01.npy',
#  '../models/topic_1_bills_clf_liblinear_new.joblib_02.npy',
#  '../models/topic_1_bills_clf_liblinear_new.joblib_03.npy']

# %%
y_test_df = pd.DataFrame(y_test)
y_test_df['true_value'] = y_test_df['Minor'].apply(lambda c: topics_map[c])
y_test_df.reset_index(drop=True, inplace=True)

prob = classifier_liblinear.decision_function(X_test)
prob_df = pd.DataFrame(prob)
columns = []
for c in classifier_liblinear.classes_:
    cname = topics_map[c]
    columns.append(cname)
prob_df.columns = columns

result_df = pd.concat([y_test_df[['true_value']], prob_df], axis=1)
result_df.to_csv('../data/test_prediction_topic_1.csv', index=False)
result_df

# %% [markdown]
# ## Try LogisticRegression

# %%
if False:
    from sklearn.linear_model import LogisticRegression

    # Perform classification with LogisticRegression
    logreg_clf = LogisticRegression()
    t0 = time.time()
    logreg_clf.fit(X_train, y_train)
    t1 = time.time()
    prediction_logreg = logreg_clf.predict(X_test)
    t2 = time.time()
    time_logreg_train = t1-t0
    time_logreg_predict = t2-t1

    print("Results for LogisticRegression()")
    print("Training time: %fs; Prediction time: %fs" % (time_logreg_train, time_logreg_predict))
    print(classification_report(y_test, prediction_logreg))
    most_informative_feature_for_class(vect, logreg_clf, 501)
#        1901       0.65      0.72      0.68        79
#        1915       1.00      0.67      0.80         3
#        1925       0.75      0.47      0.58        45
#        1926       0.90      0.60      0.72        30
#        1927       0.86      0.41      0.55        44
#        2002       0.48      0.56      0.52       192
#        2003       0.93      0.81      0.87        81
#        2006       0.97      0.89      0.93        80
#        2010       0.00      0.00      0.00         1
#        2011       0.72      0.34      0.46        86
#        2012       0.84      0.90      0.87       258
#        2013       1.00      0.31      0.47        13
#        2101       0.81      0.89      0.85       393
#        2102       0.85      0.91      0.88       429
#
# avg / total       0.71      0.68      0.68     12947
#
# 501 corpor shall 1.91150362258
# 501 except medic 1.98680220346
# 501 expos person 2.05616665776
# 501 drugfre workplac 2.31542988503
# 501 energi employe 2.39208656587
# 501 health act 2.68140984723
# 501 safeti health act 2.82936226604
# 501 occup safeti 4.17916467234
# 501 occup safeti health 4.18047942286
# 501 safeti health 6.30289325615
# 101: statist system | statist polici | price stabil | price index | data center | statist servic | feder statist servic | statist data center | statist data | feder statist
# 103: unemploy tax | employ tax | section revenu | increas unemploy | section revenu act | regul guidanc | unemploy rate | revenu act | independ contractor | busi incub
# 105: sequestr order | budget year | budget act | committe budget | deficit reduct | public debt | direct spend | budget author | congression budget | medicar choic
# 107: capit gain | section relat | incom tax | amend intern | amend intern revenu | busi entiti | section amend strike | revenu servic | intern revenu servic | sale tax
# 201: advisori group | elimin racial | elimin racial profil | enforc agenc | state attorney | law enforc agenc | custom servic personnel | unit state attorney | institut slaveri | racial profil
# 202: right act usc | basi sexual orient | basi sexual | perman partnership | civil right act | civil right | sexual harass | perman partner | child support | sexual orient
# 206: voter registr | uniform servic voter | servic voter | absente ballot | elect offici | feder offic | elect feder offic | elect feder | vote right | vote system
# 207: religi freedom peac | peac tax | freedom peac tax | flag unit state | flag unit | reproduct health | perform abort | unborn child | religi freedom | partialbirth abort
# 209: detain unit | detain unit state | state citizen | unit state citizen | anoth countri | ensur citizen | secur screener | time war | transport secur | covert test
# 301: health secur | item servic | health board | care servic | commun health | state health | health inform | nation health | region allianc | health plan
# 302: item servic | titl xviii | medihealth plan | medic care | hapi plan | health coverag | independ home | health plan | health benefit | health insur
# 323: provid servic | physician servic | servic furnish | amend titl xviii | medicar program | fee schedul | titl xviii social | xviii social | xviii social secur | titl xviii
# 324: care liabil | health care liabil | medic malpractic insur | health care fraud | care fraud | medicar program | malpractic insur | patient safeti | fraud abus | medic malpractic
# 331: public health emerg | center diseas | prostat cancer | control prevent | health servic act | public health servic | lyme diseas | agent toxin | physic activ | influenza vaccin
# 332: titl xix | children health | titl xxi | mental health | fetal alcohol | health plan | child health | health servic act | public health servic | pregnant women
# 333: marriag famili | veteran affair | postpartum depress | individu autism | spectrum disord | autism spectrum disord | mental health servic | autism spectrum | mental ill | mental health
# 335: cover outpati drug | outpati drug | item servic | cover outpati | secur futur | immunosuppress drug | medicar advantag | medicar beneficiari | drug biolog | prescript drug
# 403: feder food | food drug cosmet | drug cosmet | food establish | genet engin | food drug | food product | poultri product | tobacco product | food safeti
