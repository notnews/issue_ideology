# %% [markdown]
# 1. predict 'Minor': column labeled 'minor'
# 2. predict 'Major': column labeled 'major'
# 3. predict only categories where topic_code.csv (also in opt/data) says include ==1 (I will update this soon.)
#
#
# How?
# 1. Tokenize bill text
# 2. Break into 5000 word chunks per bill
# 3. Use SVM to predict --- cross-validate to tune
# 4. Show classification success and print out top coefficients for each category so that we can verify that the model makes sense

# %%
import pandas as pd
import numpy as np
import time

# %% [markdown]
# ## Read Bills dataset (cleaned version)

# %%
df = pd.read_csv('../data/bills-out-clean.csv.gz', nrows=10)
df.columns
# Out:
# Index([u'uid', u'Major', u'Minor', u'clean_text'], dtype='object')

# %%
df = pd.read_csv('../data/bills-out-clean.csv.gz', usecols=['Major', 'Minor', 'clean_text'])

# %% [markdown]
# ## Split long bill to smaller chunk (5000 words)

# %%
import re
def insert_split_marker(text, wc=1000):
    text = re.sub('\d+', '', text)
    words = text.split()
    out = ''
    for i, w in enumerate(words):
        if i != 0 and i % wc == 0:
            out += ' | ' + w
        else:
            out += ' ' + w
    return out

# %%
df['clean_text'] = df['clean_text'].apply(lambda c: insert_split_marker(c, 5000))

# %%
s = df['clean_text'].str.split('|', expand=True).stack()
i = s.index.get_level_values(0)
new_df = df.loc[i].copy()
new_df['chunk'] = s.index.get_level_values(1)
new_df['clean_text'] = s.values
new_df
# Out:
#        Major  Minor                                         clean_text  chunk
# 0         20   2012   congression bill th congress us govern print ...      0
# 0         20   2012   period end date evennumb calendar year regula...      1
# 1          3    300   congression bill th congress us govern print ...      0
# 1          3    300   health servic act amend section respect agree...      1
# 1          3    300   establish criteria valid regulatori accept al...      2
# 1          3    300   program sec revis extens certain program titl...      3
# 2         15   1520   congression bill th congress us govern print ...      0
# 3         20   2000   congression bill th congress us govern print ...      0
# 4         15   1522   congression bill th congress us govern print ...      0
# 5          1    107   congression bill th congress us govern print ...      0
# 6         14   1401   congression bill th congress us govern print ...      0
# 6         14   1401   asset continu period immedi preced transfer h...      1
# 6         14   1401   agreement provid accord section job guarante ...      2
# 7          1    107   congression bill th congress us govern print ...      0
# 7          1    107   strike follow ii insert except state may allo...      1
# 8         14   1406   congression bill th congress us govern print ...      0
# 9          3    331   congression bill th congress us govern print ...      0
# 10        20   2012   congression bill th congress us govern print ...      0
# 11         3    301   congression bill th congress us govern print ...      0
# 11         3    301   b gener acut care hospit date applic describ ...      1
# 11         3    301   price consist fair market valu gener avail re...      2
# 11         3    301   g shall take effect juli shall appli individu...      3
# 12        18   1806   congression bill th congress us govern print ...      0
# 13         2    207   congression bill th congress us govern print ...      0
# 14        15   1504   congression bill th congress us govern print ...      0
# 15         6    601   congression bill th congress us govern print ...      0
# 16         3    302   congression bill th congress us govern print ...      0
# 16         3    302   technic assist includ actuari servic may requ...      1
# 17        16   1609   congression bill th congress us govern print ...      0
# 18        13   1303   congression bill th congress us govern print ...      0
# ...      ...    ...                                                ...    ...
# 25327     20   2006   congression bill th congress us govern print ...      0
# 25328      3    321   congression bill th congress us govern print ...      0
# 25329      3    321   congression bill th congress us govern print ...      0
# 25330     10   1003   congression bill th congress us govern print ...      0
# 25331     20   2012   congression bill th congress us govern print ...      0
# 25332     21   2103   congression bill th congress us govern print ...      0
# 25333     12   1210   congression bill th congress us govern print ...      0
# 25334      3    321   congression bill th congress us govern print ...      0
# 25335     17   1701   congression bill th congress us govern print ...      0
# 25336     12   1211   congression bill th congress us govern print ...      0
# 25337     20   2001   congression bill th congress us govern print ...      0
# 25338     15   1525   congression bill th congress us govern print ...      0
# 25339      7    711   congression bill th congress us govern print ...      0
# 25340     12   1210   congression bill th congress us govern print ...      0
# 25341     15   1521   congression bill th congress us govern print ...      0
# 25341     15   1521   strike recipi assist insert elig entiti ii st...      1
# 25341     15   1521   act usc q amend strike mean veteran follow in...      2
# 25342      5    530   congression bill th congress us govern print ...      0
# 25343      6    602   congression bill th congress us govern print ...      0
# 25344      1    104   congression bill th congress us govern print ...      0
# 25345     13   1303   congression bill th congress us govern print ...      0
# 25346     15   1521   congression bill th congress us govern print ...      0
# 25347     15   1523   congression bill th congress us govern print ...      0
# 25348      7    710   congression bill th congress us govern print ...      0
# 25349     20   2006   congression bill th congress us govern print ...      0
# 25350      1    107   congression bill th congress us govern print ...      0
# 25351     15   1502   congression bill th congress us govern print ...      0
# 25352     13   1303   congression bill th congress us govern print ...      0
# 25353     21   2101   congression bill th congress us govern print ...      0
# 25354      7    704   congression bill th congress us govern print ...      0
#
# [28739 rows x 4 columns]

# %% [markdown]
# ## Vectorize

# %%
import nltk
from nltk import word_tokenize          
from nltk.stem.porter import PorterStemmer
import re
import string

stemmer = PorterStemmer()
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

#def tokenize(text):
#    tokens = nltk.word_tokenize(text)
#    stems = stem_tokens(tokens, stemmer)
#    return stems

def tokenize(text):
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    return stems

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.cross_validation import train_test_split

# %%
#vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3), min_df=0.01)
vect = CountVectorizer(ngram_range=(2, 3), min_df=0.01) 
#vect = CountVectorizer(ngram_range=(2, 3)) 
vect.fit(df.clean_text)
# Out:
# CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=0.01,
#         ngram_range=(2, 3), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
len(vect.get_feature_names())
# Out:
# 10114

# %%
ng_df = pd.DataFrame(vect.get_feature_names())
ng_df.columns = ['ngram']
ng_df
# Out:
#                            ngram
# 0                       aa amend
# 1                aa amend strike
# 2                      aa strike
# 3                        aa titl
# 4                       ab amend
# 5                ab amend strike
# 6                        ab titl
# 7                       ac amend
# 8                    academ year
# 9                 academi scienc
# 10              accept secretari
# 11                    accept use
# 12                 access health
# 13                 access inform
# 14                    access use
# 15              accompani inform
# 16             accomplish purpos
# 17                    accord act
# 18                 accord applic
# 19             accord applic law
# 20               accord criteria
# 21                 accord follow
# 22                  accord gener
# 23               accord guidelin
# 24                    accord law
# 25              accord paragraph
# 26               accord procedur
# 27                 accord provis
# 28         accord provis section
# 29                  accord regul
# ...                          ...
# 10084          year shall exceed
# 10085           year shall reduc
# 10086               year special
# 10087                 year state
# 10088                year strike
# 10089               year subject
# 10090          year subparagraph
# 10091  year subparagraph thereof
# 10092               year subsect
# 10093               year subsequ
# 10094        year subsequ fiscal
# 10095               year succeed
# 10096        year succeed fiscal
# 10097                   year sum
# 10098               year sum may
# 10099                year taxabl
# 10100           year taxabl year
# 10101                year taxpay
# 10102                  year term
# 10103              year thereaft
# 10104    year thereaft secretari
# 10105                  year time
# 10106                  year titl
# 10107                 year total
# 10108                  year unit
# 10109            year unit state
# 10110                year unless
# 10111                   year use
# 10112                  year year
# 10113                    york mr
#
# [10114 rows x 1 columns]

# %%
#ng_df.to_csv('../data/bills-23gram.csv', index=False)

# %%
def most_informative_feature_for_class(vectorizer, classifier, classlabel, n=10):
    labelid = list(classifier.classes_).index(classlabel)
    feature_names = vectorizer.get_feature_names()
    topn = sorted(zip(classifier.coef_[labelid], feature_names))[-n:]

    for coef, feat in topn:
        print classlabel, feat, coef

def most_informative_feature_for_class_svm(vectorizer, classifier,  n=10):
    labelid = 3 # this is the coef we're interested in. 
    feature_names = vectorizer.get_feature_names()
    svm_coef = classifier.coef_.toarray() 
    topn = sorted(zip(svm_coef[labelid], feature_names))[-n:]

    for coef, feat in topn:
        print feat, coef

def print_top10(vectorizer, clf, class_labels):
    """Prints features with the highest coefficient values, per class"""
    feature_names = vectorizer.get_feature_names()
    for i, class_label in enumerate(class_labels):
        top10 = np.argsort(clf.coef_[i])[-10:]
        print("%s: %s" % (class_label,
              " | ".join(feature_names[j] for j in top10)))

# %% [markdown]
# ## Model (Major)

# %%
df.groupby('Major').agg({'Major': 'count'})
# Out:
#        Major
# Major
# 1       1021
# 2        539
# 3       2869
# 4        558
# 5       1429
# 6       1153
# 7       1228
# 8        979
# 10       973
# 12      1570
# 13       650
# 14       478
# 15      1687
# 16      1481
# 17       514
# 18      2395
# 19       732
# 20      2390
# 21      2308
# 99       401

# %%
X = df.clean_text
y = df.Major

X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
X_train = vect.transform(X_train)
transformer = TfidfTransformer()
X_train = transformer.fit_transform(X_train)

# %%
X_test = vect.transform(X_test)
transformer = TfidfTransformer()
X_test = transformer.fit_transform(X_test)

# %%
# Perform classification with SVM, kernel=linear
classifier_liblinear = svm.LinearSVC()
t0 = time.time()
classifier_liblinear.fit(X_train, y_train)
t1 = time.time()
prediction_liblinear = classifier_liblinear.predict(X_test)
t2 = time.time()
time_liblinear_train = t1-t0
time_liblinear_predict = t2-t1

print("Results for LinearSVC")
print("Training time: %fs; Prediction time: %fs" % (time_liblinear_train, time_liblinear_predict))
print(classification_report(y_test, prediction_liblinear))
# Out:
# Results for LinearSVC()
# Training time: 9.335489s; Prediction time: 0.052043s
#              precision    recall  f1-score   support
#
#           1       0.52      0.60      0.55       204
#           2       0.57      0.35      0.43       108
#           3       0.83      0.89      0.86       574
#           4       0.72      0.65      0.69       112
#           5       0.76      0.73      0.75       286
#           6       0.81      0.79      0.80       231
#           7       0.76      0.69      0.72       246
#           8       0.76      0.76      0.76       196
#          10       0.71      0.77      0.74       195
#          12       0.70      0.72      0.71       314
#          13       0.71      0.69      0.70       130
#          14       0.70      0.65      0.67        96
#          15       0.67      0.67      0.67       337
#          16       0.69      0.69      0.69       296
#          17       0.70      0.70      0.70       103
#          18       0.93      0.93      0.93       479
#          19       0.69      0.66      0.68       146
#          20       0.76      0.73      0.74       478
#          21       0.78      0.86      0.82       462
#          99       0.91      0.79      0.85        80
#
# avg / total       0.75      0.75      0.75      5073

# %%
most_informative_feature_for_class(vect, classifier_liblinear, 99)
#most_informative_feature_for_class_svm(vect, classifier_linear)
# Out:
# 99 appropri fee 0.761935747865
# 99 oper nation 0.806987489961
# 99 servic render 0.848222848601
# 99 shall paid 1.00985892779
# 99 legisl day 1.01397596396
# 99 time limit 1.33071359277
# 99 judiciari bill relief 1.66424232091
# 99 presid author 1.66799803254
# 99 bill relief 2.99838258892
# 99 session relief 3.05795669245

# %%
print_top10(vect, classifier_liblinear, classifier_liblinear.classes_)
# Out:
# 1: receiv individu | avail secretari | basi properti | recipi assist | minimum tax | made decemb | domest product | section tax | congression budget | feder tax
# 2: may obtain | civil right | right act | account number | may disclos | person identifi | employ opportun | person inform | nation origin | amend constitut
# 3: medic servic | children health | titl xviii | amend titl xviii | public health servic | health insur | health care | prescript drug | care act | medic care
# 4: agricultur bill | relat tax | agricultur commod | committe agricultur bill | rule certain | section ae | refer committe agricultur | secretari agricultur | committe agricultur | section agricultur
# 5: individu employ | depart labor | plan purpos | immigr nation | occup safeti | individu retir | respons act | retir incom | job train | unemploy compens
# 6: elementari secondari | profession develop | higher educ | educ act | educ expens | educ assist | relat expens | student loan | public school | secretari educ
# 7: control act | issu state | pollut control | solid wast | polici act | endang speci | nation environment | manag act usc | drink water | manag act
# 8: public util | regulatori commiss | energi conserv | atom energi | electr power | secretari energi | natur ga | energi polici | power act | oil ga
# 10: stat amend | merchant marin | administr feder | secur administr | insur corpor | depart transport | transport infrastructur | transport system | feder aviat | secretari transport
# 12: feder court | person convict | plan program | judici district | violent crime | term child | children famili | child support | committe judiciari | refer committe judiciari
# 13: poverti line | servic program | individu disabl | commun servic | receiv benefit | disabl act | section food | social servic | social secur | nation school
# 14: urban area | public hous | econom develop | commun develop | respect elig | servic date | princip resid | strateg plan | low incom | hous act
# 15: exchang act | pro rata | refer committe bank | insur program | fund transfer | insur compani | disast relief | report act | consum protect | small busi
# 16: assist fund | arm forc | arm servic bill | depart defens | nation secur | refer committe veteran | servic bill amend | refer committe arm | nation guard | homeland secur
# 17: public educ | feder commun commiss | commun commiss | servic commun | feder commun | feder entiti | equip use | commun act usc | committe scienc | commun act
# 18: exclus certain | trade act usc | trade act | export control | trade agreement | enhanc act | corpor partnership | tariff act | tax paid | administr act
# 19: human right | nongovernment organ | execut order | author unit | unit nation | committe foreign affair | foreign assist | unit state intern | relat bill | refer committe foreign
# 20: elect offici | postal servic | govern oper | feder elect | district columbia | refer committe hous | member congress | elect campaign | known design | committe rule
# 21: certain land | committe resourc | indian affair | water resourc | indian tribe | held trust | section indian | indian tribal | refer committe resourc | indian reserv
# 99: appropri fee | oper nation | servic render | shall paid | legisl day | time limit | judiciari bill relief | presid author | bill relief | session relief

# %%
from sklearn.linear_model import SGDClassifier

elastic_clf = SGDClassifier(loss='log', alpha=.00002, n_iter=200, penalty="elasticnet")
t0 = time.time()
elastic_clf.fit(X_train, y_train)
t1 = time.time()
prediction_elastic = elastic_clf.predict(X_test)
t2 = time.time()
time_elastic_train = t1-t0
time_elastic_predict = t2-t1

print("Results for Elastic Net")
print("Training time: %fs; Prediction time: %fs" % (time_elastic_train, time_elastic_predict))
print(classification_report(y_test, prediction_elastic))
# Out:
# Results for Elastic Net
# Training time: 404.283877s; Prediction time: 0.067536s
#              precision    recall  f1-score   support
#
#           1       0.46      0.67      0.55       204
#           2       0.69      0.32      0.44       108
#           3       0.82      0.88      0.85       574
#           4       0.68      0.62      0.65       112
#           5       0.78      0.71      0.74       286
#           6       0.82      0.78      0.80       231
#           7       0.79      0.64      0.71       246
#           8       0.79      0.73      0.76       196
#          10       0.71      0.74      0.73       195
#          12       0.67      0.70      0.69       314
#          13       0.74      0.68      0.71       130
#          14       0.73      0.60      0.66        96
#          15       0.64      0.65      0.64       337
#          16       0.66      0.67      0.66       296
#          17       0.72      0.63      0.67       103
#          18       0.92      0.92      0.92       479
#          19       0.70      0.64      0.67       146
#          20       0.72      0.73      0.73       478
#          21       0.78      0.86      0.82       462
#          99       0.91      0.78      0.84        80
#
# avg / total       0.75      0.74      0.74      5073

# %%
most_informative_feature_for_class(vect, elastic_clf, 99)
# Out:
# 99 secretari treasuri 2.27162756979
# 99 refer committe judiciari 2.33396247279
# 99 servic render 2.46314464558
# 99 custom servic 2.5113799946
# 99 immigr visa 3.08030179582
# 99 presid author 3.46982699131
# 99 time limit 3.76281213036
# 99 judiciari bill relief 4.85264480504
# 99 session relief 8.33809740652
# 99 bill relief 8.43836098626

# %%
print_top10(vect,  elastic_clf,  elastic_clf.classes_)
# Out:
# 1: econom growth | reconcili act | minimum tax | feder reserv | secretari treasuri | tax relief | incom tax | fiscal year | feder tax | congression budget
# 2: feder offic | privat properti | person identifi | employ opportun | nation origin | account number | amend constitut | right act | civil right | person inform
# 3: public health servic | health benefit | social secur act | medicar program | titl xviii | health insur | medic care | care act | health care | prescript drug
# 4: invest act | secretari shall | depart agricultur | agricultur bill | agricultur commod | committe agricultur bill | refer committe agricultur | secretari agricultur | section agricultur | committe agricultur
# 5: occup safeti | respons act | nation act | labor relat | immigr nation act | individu retir | immigr nation | job train | child care | unemploy compens
# 6: educ institut | elementari secondari | educ expens | relat expens | educ act | higher educ | student loan | secretari educ | public school | educ assist
# 7: polici act | control act | administr shall | nation environment | environment protect | manag act usc | endang speci | solid wast | drink water | manag act
# 8: energi conserv | depart energi | atom energi | energi effici | regulatori commiss | secretari energi | energi polici | power act | natur ga | oil ga
# 10: motor vehicl | transport bill | public work | insur corpor | merchant marin | depart transport | transport system | transport infrastructur | feder aviat | secretari transport
# 12: court appeal | control substanc | violent crime | committe judiciari bill | judiciari bill | domest violenc | law enforc | child support | committe judiciari | refer committe judiciari
# 13: insur benefit | servic program | state program | earn incom | individu disabl | social servic | disabl act | commun servic | nation school | social secur
# 14: hous urban | strateg plan | public hous | develop act | urban area | econom develop | low incom | commun develop | princip resid | hous act
# 15: insur program | fund transfer | intellectu properti | secur exchang | consum protect | report act | insur compani | exchang act | disast relief | small busi
# 16: air forc | refer committe veteran | arm servic bill | uniform servic | depart defens | refer committe arm | arm forc | nation secur | nation guard | homeland secur
# 17: servic provid | equip use | commun servic | rural area | commun commiss | feder commun | feder commun commiss | commun act usc | committe scienc | commun act
# 18: north american | foreign govern | committe financ | secretari commerc | good servic | administr act | trade agreement | tariff act | unit state | trade act
# 19: terrorist attack | develop countri | human right | foreign assist | committe foreign | secretari state | unit nation | relat bill | refer committe foreign | unit state
# 20: feder employe | refer committe hous | known design | polit parti | committe rule | postal servic | district columbia | elect campaign | feder elect | member congress
# 21: nation histor | nation forest | puerto rico | water resourc | committe resourc | nativ american | indian tribal | refer committe resourc | indian reserv | indian tribe
# 99: secretari treasuri | refer committe judiciari | servic render | custom servic | immigr visa | presid author | time limit | judiciari bill relief | session relief | bill relief

# %% [markdown]
# ## Model (Minor)

# %%
sdf = df.groupby('Minor').agg({'Minor': 'count'})
minors = sdf[sdf.Minor > 200].index
minors
# Out:
# Int64Index([ 107,  208,  301,  302,  321,  331,  332,  402,  503,  530,  601,
#              602,  709,  803, 1003, 1007, 1204, 1208, 1209, 1303, 1501, 1521,
#             1523, 1608, 1609, 1807, 2002, 2004, 2008, 2012, 2101, 2102, 2103,
#             2104, 9999],
#            dtype='int64', name=u'Minor')

# %%
X = df[df.Minor.isin(minors)].clean_text
y = df[df.Minor.isin(minors)].Minor

X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
X_train = vect.transform(X_train)
transformer = TfidfTransformer()
X_train = transformer.fit_transform(X_train)

# %%
X_test = vect.transform(X_test)
transformer = TfidfTransformer()
X_test = transformer.fit_transform(X_test)

# %%
# Perform classification with SVM, kernel=linear
classifier_liblinear = svm.LinearSVC()
t0 = time.time()
classifier_liblinear.fit(X_train, y_train)
t1 = time.time()
prediction_liblinear = classifier_liblinear.predict(X_test)
t2 = time.time()
time_liblinear_train = t1-t0
time_liblinear_predict = t2-t1

print("Results for LinearSVC()")
print("Training time: %fs; Prediction time: %fs" % (time_liblinear_train, time_liblinear_predict))
print(classification_report(y_test, prediction_liblinear))
# Out:
# Results for LinearSVC()
# Training time: 5.939257s; Prediction time: 0.039521s
#              precision    recall  f1-score   support
#
#         107       0.65      0.82      0.72       152
#         208       0.71      0.48      0.57        42
#         301       0.50      0.40      0.44        43
#         302       0.59      0.60      0.59        95
#         321       0.77      0.73      0.75        41
#         331       0.61      0.67      0.64        42
#         332       0.60      0.66      0.63        41
#         402       0.77      0.73      0.75        41
#         503       0.69      0.68      0.68        81
#         530       0.80      0.90      0.84        97
#         601       0.88      0.70      0.78        87
#         602       0.78      0.82      0.80        65
#         709       0.77      0.72      0.74        67
#         803       0.68      0.65      0.67        63
#        1003       0.83      0.80      0.82        50
#        1007       0.80      0.75      0.77        52
#        1204       0.57      0.71      0.63        45
#        1208       0.83      0.71      0.77        49
#        1209       0.68      0.73      0.70        63
#        1303       0.82      0.71      0.76        58
#        1501       0.74      0.79      0.76        47
#        1521       0.82      0.79      0.81        58
#        1523       0.73      0.63      0.68        52
#        1608       0.69      0.66      0.68        65
#        1609       0.69      0.69      0.69        78
#        1807       0.98      0.99      0.99       407
#        2002       0.68      0.53      0.60        43
#        2004       0.73      0.71      0.72        63
#        2008       0.89      0.88      0.89       104
#        2012       0.91      0.84      0.87        61
#        2101       0.74      0.84      0.78       160
#        2102       0.84      0.87      0.85        87
#        2103       0.76      0.67      0.71       121
#        2104       0.76      0.83      0.80        66
#        9999       0.95      0.90      0.92        80
#
# avg / total       0.78      0.78      0.78      2766

# %%
most_informative_feature_for_class(vect, classifier_liblinear, 9999)
# Out:
# 9999 person violat 0.843023633852
# 9999 refer committe judiciari 0.886832131244
# 9999 sec nation 0.897203798013
# 9999 usc section 1.04024143168
# 9999 servic render 1.04533424117
# 9999 presid author 1.54521015975
# 9999 judiciari bill relief 1.695195477
# 9999 time limit 1.86713237437
# 9999 bill relief 3.10942289715
# 9999 session relief 3.16347633549

# %%
print_top10(vect, classifier_liblinear, classifier_liblinear.classes_)
# Out:
# 107: made date | basi properti | made decemb | intern revenu | invest compani | incom tax | princip resid | feder tax | reconcili act | minimum tax
# 208: inform obtain | requir state | written consent | use inform | provis act | inform individu | person identifi | inform act | account number | person inform
# 301: amend strike | amount provid | health center | commun health | urban area | racial ethnic | medic care | rural area | health care | care act
# 302: limit number | elig individu | individu enrol | benefit part | care act | rule certain | medic care | medic treatment | medic servic | health insur
# 321: food drug administr | feder food | feder food drug | act respect | relat tax | final rule | emerg medic | market price | food drug | prescript drug
# 331: diseas control prevent | control prevent | diseas control | shall ensur | center diseas | grant loan | medicar program | period servic | public health | diagnosi treatment
# 332: state plan | section act usc | famili incom | benefit servic | state use | educ program | public health servic | titl xxi | children health | child health
# 402: agricultur bill | determin secretari | particip state | committe agricultur bill | secretari agricultur | invest act | rural develop | committe agricultur | refer committe agricultur | section agricultur
# 503: benefit shall | employ employe | employe employe | number employe | plan purpos | health profession | employe employ | retir incom | individu retir | unemploy compens
# 530: attorney gener | fair act | unit state | committe judiciari | person respons | alien law | nation act | immigr nation act | immigr nation | respons act
# 601: st centuri | organ describ | educ act | loan repay | higher educ act | secretari educ | relat expens | student loan | higher educ | educ assist
# 602: revolv fund | educ institut | local educ agenc | local educ | educ expens | elementari secondari educ | nation school | secondari educ | public school | elementari secondari
# 709: solid wast | speci act | protect act | author state | state offici | drink water | endang speci | conserv act | manag act usc | manag act
# 803: hazard materi | use appropri | per day | grant recipi | research develop | energi effici | secretari energi | natur ga | energi polici | oil ga
# 1003: state code relat | vote member | code exempt | aviat administr | feder aviat administr | administr feder | transport shall | member appoint | secur administr | feder aviat
# 1007: labor organ | third parti | nation defens | unit state | transport infrastructur | transport system | usc app | secretari transport | merchant marin | coast guard
# 1204: fee cost | attorney fee | committe judiciari | rule feder | court appeal | suprem court | judici district | feder rule | district court | feder court
# 1208: iv social secur | titl iv social | care provid | assist program | act respect | plan program | children famili | titl public | domest violenc | child support
# 1209: emerg medic | committe judiciari bill | depart agenc | judiciari bill | local law | system nation | control act | unlaw person | law enforc | violent crime
# 1303: ii social secur | sentenc paragraph | ii social | disabl insur | titl ii | alleg violat | assist secretari | longterm care | insur benefit | social secur
# 1501: report act | refer committe bank | depositori institut | credit union | deposit insur | committe bank | financi servic | pro rata | feder reserv | fund transfer
# 1521: person servic | qualifi health | princip place busi | respect contract | consum protect | appli purpos | shall appli purpos | busi develop | employe health | small busi
# 1523: feder emerg manag | feder emerg | addit amount | director shall | emerg manag | insur coverag | terrorist attack | insur compani | insur program | disast relief
# 1608: qualiti life | committe arm servic | air forc | committe arm | arm servic | relief act | year age | arm forc | servic bill amend | uniform servic
# 1609: assist fund | committe veteran affair | servic connect | veteran affair | committe veteran | paid state | veteran affair bill | rate percent | member board | refer committe veteran
# 1807: committe financ bill | financ bill | agreement act | refer committe financ | corpor partnership | mean bill extend | foreign countri | import unit state | import unit | tariff act
# 2002: present valu | renew energi | perform function | committe rule | financi manag | financi statement | joint resolut | agenc program | public servic | inspector gener
# 2004: subparagraph paragraph | offic personnel manag | employe retir | offic personnel | feder law enforc | member congress | public safeti | servic employe | civil servic | feder employe
# 2008: administr gener servic | nation institut | post offic | properti administr | act design | refer refer | law regul | known design | research center | feder properti
# 2012: person entiti | vice presid | state local | telephon number | report requir | elect campaign | polit parti | feder offic | elect offici | feder elect
# 2101: number date | area shall | establish nation | public use | histor preserv | author establish | design nation | nation histor | amend nation | nation park
# 2102: tribe shall | indian affair | indian health | settlement act | held trust | section indian | indian tribal | nativ american | indian reserv | indian tribe
# 2103: certain feder | state indian | restrict use | feder land | properti subject | certain land | state indian tribe | approxim acr | land state | nation forest
# 2104: reform act | ms snow | state interest | feasibl studi | water conserv | secretari armi | corp engin | project author | water resourc | water suppli
# 9999: person violat | refer committe judiciari | sec nation | usc section | servic render | presid author | judiciari bill relief | time limit | bill relief | session relief
